# %% [markdown]
# # Exploratory data analysis

# %% [markdown]
# ## Table of contents
#
# 0. [Introduction](#Introduction)
# 1. [Import of packages](#Packages)
# 2. [Import of functions](#Functions)
# 3. [Import of data](#Data)
#     1. [Adjusting the dataframe to enhance analyses](#Adjusting)
#         1. [Category](#CategoryAdjusting)
#         2. [Duplicates](#DuplicatesAdjusting)
#         3. [Missing](#MissingAdjusting)
#     2. [Spliting the dataframe](#Spliting)
# 4. [Results](#EDAResults)
#     1. [Initial informations ](#InitialResults)
#     2. [Overview](#OverviewResults)
#     3. [Categorical variables distributions](#CategoricalDistributionsResults)
#     4. [Numeric variables distributions](#NumericDistributionsResults)
#     5. [Target proportion](#ProportionResults)
#     6. [Numeric variables correlation](#NumericVariablesCorrelationResults)

# %% [markdown]
# <section id="Introduction">
#     <h2> 0. Introduction </h2>
# </section>

# %% [markdown]
# This is a file with functions that aim to facilitate exploratory data analysis. As output, the functions provide graphs, metrics, and basic tables commonly used in the analysis process. Pay attention to the function parameters:
#
# - **df_origin**: single pandas dataframe;
#
# <br>
#
# - **X_train**: pandas train dataframe;
# - **X_test**: pandas test dataframe;
# - **X_validation**: pandas validation dataframe;
#
# <br>
#
# - **y_train**: train target;
# - **y_test**: test target;
# - **y_validation**: validation target;

# %% [markdown]
# ---

# %% [markdown]
# <section id="Packages">
#     <h2> 1. Import of packages </h2>
# </section>

# %%
#!pip install

# %%
from sklearn.datasets import load_breast_cancer

from fast_ml import eda
from fast_ml.model_development import train_valid_test_split
from fast_ml.utilities import reduce_memory_usage, display_all

import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import pickle # pickle
import pyarrow

# interative interface
import ipywidgets as widgets
from IPython.display import display

# %% [markdown]
# <section id="Functions">
#     <h2> 2. Import of Functions </h2>
# </section>

# %%
import os
print(os.getcwd())
# Out:
# /home/744ef240-a25d-4872-a66e-1d945ea1adf7/model_analysis/jupyter_notebooks/EDA

# %%
# %run "/home/744ef240-a25d-4872-a66e-1d945ea1adf7/model_analysis/jupyter_notebooks/EDA/model_analysis-eda-functions.ipynb"

# %% [markdown]
# <section id="Data">
#     <h2> 3. Import of data </h2>
# </section>

# %%
X_origin, y_origin = load_breast_cancer(return_X_y=True, as_frame=True)

# %%
y_dataframe = pd.DataFrame(y_origin, columns=['target'])

# %%
df_origin = pd.concat([X_origin, y_dataframe], axis=1)

# %%
df_origin
# Out:
#      mean radius  mean texture  mean perimeter  mean area  mean smoothness  \
# 0          17.99         10.38          122.80     1001.0          0.11840
# 1          20.57         17.77          132.90     1326.0          0.08474
# 2          19.69         21.25          130.00     1203.0          0.10960
# 3          11.42         20.38           77.58      386.1          0.14250
# 4          20.29         14.34          135.10     1297.0          0.10030
# ..           ...           ...             ...        ...              ...
# 564        21.56         22.39          142.00     1479.0          0.11100
# 565        20.13         28.25          131.20     1261.0          0.09780
# 566        16.60         28.08          108.30      858.1          0.08455
# 567        20.60         29.33          140.10     1265.0          0.11780
# 568         7.76         24.54           47.92      181.0          0.05263
#
#      mean compactness  mean concavity  mean concave points  mean symmetry  \
# 0             0.27760         0.30010              0.14710         0.2419
# 1             0.07864         0.08690              0.07017         0.1812
# 2             0.15990         0.19740              0.12790         0.2069
# 3             0.28390         0.24140              0.10520         0.2597
# 4             0.13280         0.19800              0.10430         0.1809
# ..                ...             ...                  ...            ...
# 564           0.11590         0.24390              0.13890         0.1726
# 565           0.10340         0.14400              0.09791         0.1752
# 566           0.10230         0.09251              0.05302         0.1590
# 567           0.27700         0.35140              0.15200         0.2397
# 568           0.04362         0.00000              0.00000         0.1587
#
#      mean fractal dimension  ...  worst texture  worst perimeter  worst area  \
# 0                   0.07871  ...          17.33           184.60      2019.0
# 1                   0.05667  ...          23.41           158.80      1956.0
# 2                   0.05999  ...          25.53           152.50      1709.0
# 3                   0.09744  ...          26.50            98.87       567.7
# 4                   0.05883  ...          16.67           152.20      1575.0
# ..                      ...  ...            ...              ...         ...
# 564                 0.05623  ...          26.40           166.10      2027.0
# 565                 0.05533  ...          38.25           155.00      1731.0
# 566                 0.05648  ...          34.12           126.70      1124.0
# 567                 0.07016  ...          39.42           184.60      1821.0
# 568                 0.05884  ...          30.37            59.16       268.6
#
#      worst smoothness  worst compactness  worst concavity  \
# 0             0.16220            0.66560           0.7119
# 1             0.12380            0.18660           0.2416
# 2             0.14440            0.42450           0.4504
# 3             0.20980            0.86630           0.6869
# 4             0.13740            0.20500           0.4000
# ..                ...                ...              ...
# 564           0.14100            0.21130           0.4107
# 565           0.11660            0.19220           0.3215
# 566           0.11390            0.30940           0.3403
# 567           0.16500            0.86810           0.9387
# 568           0.08996            0.06444           0.0000
#
#      worst concave points  worst symmetry  worst fractal dimension  target
# 0                  0.2654          0.4601                  0.11890       0
# 1                  0.1860          0.2750                  0.08902       0
# 2                  0.2430          0.3613                  0.08758       0
# 3                  0.2575          0.6638                  0.17300       0
# 4                  0.1625          0.2364                  0.07678       0
# ..                    ...             ...                      ...     ...
# 564                0.2216          0.2060                  0.07115       0
# 565                0.1628          0.2572                  0.06637       0
# 566                0.1418          0.2218                  0.07820       0
# 567                0.2650          0.4087                  0.12400       0
# 568                0.0000          0.2871                  0.07039       1
#
# [569 rows x 31 columns]

# %% [markdown]
# <section id="Adjusting">
#     <h3> 3.1. Adjusting the dataframe to enhance analyses </h3>
# </section>

# %% [markdown]
# <section id="CategoryAdjusting">
#     <h4> 3.1.1. Category </h4>
# </section>

# %%
categories = ['A', 'B', 'C']

df_origin['false category'] = np.random.choice(categories, size=len(df_origin))
df_origin['false category2'] = np.random.choice(categories, size=len(df_origin))
df_origin['false category3'] = np.random.choice(categories, size=len(df_origin))

# %%
df_origin
# Out:
#      mean radius  mean texture  mean perimeter  mean area  mean smoothness  \
# 0          17.99         10.38          122.80     1001.0          0.11840
# 1          20.57         17.77          132.90     1326.0          0.08474
# 2          19.69         21.25          130.00     1203.0          0.10960
# 3          11.42         20.38           77.58      386.1          0.14250
# 4          20.29         14.34          135.10     1297.0          0.10030
# ..           ...           ...             ...        ...              ...
# 564        21.56         22.39          142.00     1479.0          0.11100
# 565        20.13         28.25          131.20     1261.0          0.09780
# 566        16.60         28.08          108.30      858.1          0.08455
# 567        20.60         29.33          140.10     1265.0          0.11780
# 568         7.76         24.54           47.92      181.0          0.05263
#
#      mean compactness  mean concavity  mean concave points  mean symmetry  \
# 0             0.27760         0.30010              0.14710         0.2419
# 1             0.07864         0.08690              0.07017         0.1812
# 2             0.15990         0.19740              0.12790         0.2069
# 3             0.28390         0.24140              0.10520         0.2597
# 4             0.13280         0.19800              0.10430         0.1809
# ..                ...             ...                  ...            ...
# 564           0.11590         0.24390              0.13890         0.1726
# 565           0.10340         0.14400              0.09791         0.1752
# 566           0.10230         0.09251              0.05302         0.1590
# 567           0.27700         0.35140              0.15200         0.2397
# 568           0.04362         0.00000              0.00000         0.1587
#
#      mean fractal dimension  ...  worst smoothness  worst compactness  \
# 0                   0.07871  ...           0.16220            0.66560
# 1                   0.05667  ...           0.12380            0.18660
# 2                   0.05999  ...           0.14440            0.42450
# 3                   0.09744  ...           0.20980            0.86630
# 4                   0.05883  ...           0.13740            0.20500
# ..                      ...  ...               ...                ...
# 564                 0.05623  ...           0.14100            0.21130
# 565                 0.05533  ...           0.11660            0.19220
# 566                 0.05648  ...           0.11390            0.30940
# 567                 0.07016  ...           0.16500            0.86810
# 568                 0.05884  ...           0.08996            0.06444
#
#      worst concavity  worst concave points  worst symmetry  \
# 0             0.7119                0.2654          0.4601
# 1             0.2416                0.1860          0.2750
# 2             0.4504                0.2430          0.3613
# 3             0.6869                0.2575          0.6638
# 4             0.4000                0.1625          0.2364
# ..               ...                   ...             ...
# 564           0.4107                0.2216          0.2060
# 565           0.3215                0.1628          0.2572
# 566           0.3403                0.1418          0.2218
# 567           0.9387                0.2650          0.4087
# 568           0.0000                0.0000          0.2871
#
#      worst fractal dimension  target  false category  false category2  \
# 0                    0.11890       0               C                C
# 1                    0.08902       0               C                A
# 2                    0.08758       0               A                C
# 3                    0.17300       0               B                B
# 4                    0.07678       0               B                C
# ..                       ...     ...             ...              ...
# 564                  0.07115       0               C                B
# 565                  0.06637       0               B                B
# 566                  0.07820       0               A                C
# 567                  0.12400       0               B                A
# 568                  0.07039       1               B                B
#
#      false category3
# 0                  C
# 1                  B
# 2                  B
# 3                  B
# 4                  B
# ..               ...
# 564                C
# 565                C
# 566                A
# 567                C
# 568                A
#
# [569 rows x 34 columns]

# %% [markdown]
# <section id="MissingAdjusting">
#     <h4> 3.1.2. Missing </h4>
# </section>

# %%
num_rows, num_columns = df_origin.shape
missing_percent = 0.11
missing_num = int(num_rows * num_columns * missing_percent)

affected_rows = np.random.randint(0, num_rows, missing_num)
affected_columns = np.random.randint(0, num_columns, missing_num)

for row, column in zip(affected_rows, affected_columns):
    df_origin.iat[row, column] = np.nan

# %%
df_origin_missing = df_origin[df_origin['target'].notna()]

# %%
df_origin_missing
# Out:
#      mean radius  mean texture  mean perimeter  mean area  mean smoothness  \
# 0          17.99           NaN          122.80     1001.0          0.11840
# 1          20.57         17.77          132.90     1326.0          0.08474
# 2          19.69         21.25          130.00     1203.0          0.10960
# 3          11.42           NaN           77.58      386.1          0.14250
# 4          20.29         14.34          135.10     1297.0          0.10030
# ..           ...           ...             ...        ...              ...
# 561        11.20         29.37           70.67      386.0              NaN
# 562        15.22         30.62          103.40      716.9              NaN
# 563        20.92         25.09          143.00     1347.0          0.10990
# 564          NaN         22.39             NaN     1479.0          0.11100
# 568         7.76         24.54           47.92      181.0              NaN
#
#      mean compactness  mean concavity  mean concave points  mean symmetry  \
# 0             0.27760          0.3001                  NaN         0.2419
# 1             0.07864          0.0869              0.07017            NaN
# 2             0.15990          0.1974              0.12790         0.2069
# 3             0.28390          0.2414              0.10520         0.2597
# 4                 NaN          0.1980              0.10430         0.1809
# ..                ...             ...                  ...            ...
# 561           0.03558          0.0000              0.00000         0.1060
# 562           0.20870             NaN              0.09429         0.2128
# 563           0.22360          0.3174              0.14740         0.2149
# 564           0.11590          0.2439              0.13890         0.1726
# 568           0.04362             NaN              0.00000         0.1587
#
#      mean fractal dimension  ...  worst smoothness  worst compactness  \
# 0                   0.07871  ...           0.16220            0.66560
# 1                   0.05667  ...           0.12380            0.18660
# 2                   0.05999  ...           0.14440            0.42450
# 3                   0.09744  ...           0.20980            0.86630
# 4                   0.05883  ...           0.13740            0.20500
# ..                      ...  ...               ...                ...
# 561                 0.05502  ...           0.09267            0.05494
# 562                 0.07152  ...           0.14170            0.79170
# 563                     NaN  ...           0.14070            0.41860
# 564                 0.05623  ...           0.14100            0.21130
# 568                 0.05884  ...           0.08996            0.06444
#
#      worst concavity  worst concave points  worst symmetry  \
# 0             0.7119                0.2654             NaN
# 1             0.2416                0.1860             NaN
# 2             0.4504                0.2430          0.3613
# 3             0.6869                0.2575          0.6638
# 4             0.4000                0.1625             NaN
# ..               ...                   ...             ...
# 561              NaN                   NaN          0.1566
# 562           1.1700                   NaN          0.4089
# 563           0.6599                0.2542          0.2929
# 564           0.4107                0.2216          0.2060
# 568           0.0000                   NaN          0.2871
#
#      worst fractal dimension  target  false category  false category2  \
# 0                    0.11890     0.0               C                C
# 1                    0.08902     0.0               C                A
# 2                    0.08758     0.0               A                C
# 3                    0.17300     0.0               B                B
# 4                    0.07678     0.0               B                C
# ..                       ...     ...             ...              ...
# 561                  0.05905     1.0               A                B
# 562                  0.14090     0.0               C              NaN
# 563                  0.09873     0.0               A                B
# 564                  0.07115     0.0               C                B
# 568                  0.07039     1.0               B                B
#
#      false category3
# 0                  C
# 1                  B
# 2                  B
# 3                  B
# 4                  B
# ..               ...
# 561                B
# 562                B
# 563                C
# 564                C
# 568                A
#
# [511 rows x 34 columns]

# %% [markdown]
# <section id="DuplicatesAdjusting">
#     <h4> 3.1.3. Duplicates </h4>
# </section>

# %%
num_duplicates = 555

random_index = np.random.choice(df_origin_missing.index, num_duplicates, replace=True)

duplicates = df_origin_missing.loc[random_index]

df_origin_missing_duplicate = pd.concat([df_origin_missing, duplicates])

df_origin_missing_duplicate.reset_index(drop=True, inplace=True)

# %%
df_origin_missing_duplicate
# Out:
#       mean radius  mean texture  mean perimeter  mean area  mean smoothness  \
# 0           17.99           NaN          122.80     1001.0          0.11840
# 1           20.57         17.77          132.90     1326.0          0.08474
# 2           19.69         21.25          130.00     1203.0          0.10960
# 3           11.42           NaN           77.58      386.1          0.14250
# 4           20.29         14.34          135.10     1297.0          0.10030
# ...           ...           ...             ...        ...              ...
# 1061          NaN           NaN          101.70      748.9          0.10920
# 1062        27.42           NaN             NaN     2501.0          0.10840
# 1063        11.13         16.62           70.47      381.1          0.08151
# 1064        13.82           NaN           92.33      595.9          0.11620
# 1065        11.94         20.76           77.87      441.0          0.08605
#
#       mean compactness  mean concavity  mean concave points  mean symmetry  \
# 0              0.27760         0.30010                  NaN         0.2419
# 1              0.07864         0.08690              0.07017            NaN
# 2              0.15990         0.19740              0.12790         0.2069
# 3              0.28390         0.24140              0.10520         0.2597
# 4                  NaN         0.19800              0.10430         0.1809
# ...                ...             ...                  ...            ...
# 1061               NaN         0.14660              0.08087         0.1931
# 1062           0.19880         0.36350                  NaN         0.2061
# 1063           0.03834         0.01369              0.01370         0.1511
# 1064           0.16810         0.13570              0.06759         0.2275
# 1065           0.10110         0.06574              0.03791         0.1588
#
#       mean fractal dimension  ...  worst smoothness  worst compactness  \
# 0                    0.07871  ...            0.1622            0.66560
# 1                    0.05667  ...            0.1238            0.18660
# 2                    0.05999  ...            0.1444            0.42450
# 3                    0.09744  ...            0.2098            0.86630
# 4                    0.05883  ...            0.1374            0.20500
# ...                      ...  ...               ...                ...
# 1061                 0.05796  ...            0.1546            0.23940
# 1062                 0.05623  ...            0.1357            0.42560
# 1063                 0.06148  ...            0.1030            0.06219
# 1064                 0.07237  ...            0.1794            0.39660
# 1065                 0.06766  ...            0.1116            0.28130
#
#       worst concavity  worst concave points  worst symmetry  \
# 0              0.7119               0.26540             NaN
# 1              0.2416               0.18600             NaN
# 2              0.4504               0.24300          0.3613
# 3              0.6869               0.25750          0.6638
# 4              0.4000               0.16250             NaN
# ...               ...                   ...             ...
# 1061           0.3791               0.15140          0.2837
# 1062           0.6833               0.26250          0.2641
# 1063           0.0458               0.04044          0.2383
# 1064           0.3381               0.15210          0.3651
# 1065           0.2365               0.11550          0.2465
#
#       worst fractal dimension  target  false category  false category2  \
# 0                     0.11890     0.0               C                C
# 1                     0.08902     0.0               C                A
# 2                     0.08758     0.0               A                C
# 3                     0.17300     0.0               B                B
# 4                     0.07678     0.0               B                C
# ...                       ...     ...             ...              ...
# 1061                  0.08019     0.0               B                C
# 1062                  0.07427     0.0               C              NaN
# 1063                  0.07083     1.0               A                B
# 1064                  0.11830     0.0               A                A
# 1065                  0.09981     1.0               C                A
#
#       false category3
# 0                   C
# 1                   B
# 2                   B
# 3                   B
# 4                   B
# ...               ...
# 1061              NaN
# 1062                C
# 1063              NaN
# 1064                A
# 1065                B
#
# [1066 rows x 34 columns]

# %% [markdown]
# <section id="Spliting">
#     <h3> 3.2. Spliting the dataframe </h3>
# </section>

# %%
X_train, y_train, X_validation, y_validation, X_test, y_test = train_valid_test_split(
                                                        df_origin_missing_duplicate,
                                                        target = 'target',
                                                        train_size=0.8,
                                                        valid_size=0.1,
                                                        test_size=0.1)

# %% [markdown]
# ---

# %% [markdown]
# <section id="EDAResults">
#     <h2> 4. Results </h2>
# </section>

# %% [markdown]
# Note that the `df_origin` has more columns than `X_<>`, which corresponds to the target variable.

# %%
df_origin.head(5)
# Out:
#    mean radius  mean texture  mean perimeter  mean area  mean smoothness  \
# 0        17.99           NaN          122.80     1001.0          0.11840
# 1        20.57         17.77          132.90     1326.0          0.08474
# 2        19.69         21.25          130.00     1203.0          0.10960
# 3        11.42           NaN           77.58      386.1          0.14250
# 4        20.29         14.34          135.10     1297.0          0.10030
#
#    mean compactness  mean concavity  mean concave points  mean symmetry  \
# 0           0.27760          0.3001                  NaN         0.2419
# 1           0.07864          0.0869              0.07017            NaN
# 2           0.15990          0.1974              0.12790         0.2069
# 3           0.28390          0.2414              0.10520         0.2597
# 4               NaN          0.1980              0.10430         0.1809
#
#    mean fractal dimension  ...  worst smoothness  worst compactness  \
# 0                 0.07871  ...            0.1622             0.6656
# 1                 0.05667  ...            0.1238             0.1866
# 2                 0.05999  ...            0.1444             0.4245
# 3                 0.09744  ...            0.2098             0.8663
# 4                 0.05883  ...            0.1374             0.2050
#
#    worst concavity  worst concave points  worst symmetry  \
# 0           0.7119                0.2654             NaN
# 1           0.2416                0.1860             NaN
# 2           0.4504                0.2430          0.3613
# 3           0.6869                0.2575          0.6638
# 4           0.4000                0.1625             NaN
#
#    worst fractal dimension  target  false category  false category2  \
# 0                  0.11890     0.0               C                C
# 1                  0.08902     0.0               C                A
# 2                  0.08758     0.0               A                C
# 3                  0.17300     0.0               B                B
# 4                  0.07678     0.0               B                C
#
#    false category3
# 0                C
# 1                B
# 2                B
# 3                B
# 4                B
#
# [5 rows x 34 columns]

# %%
df_origin.tail(5)
# Out:
#      mean radius  mean texture  mean perimeter  mean area  mean smoothness  \
# 564          NaN         22.39             NaN     1479.0          0.11100
# 565        20.13         28.25          131.20        NaN          0.09780
# 566        16.60           NaN             NaN        NaN          0.08455
# 567        20.60         29.33          140.10     1265.0          0.11780
# 568         7.76         24.54           47.92      181.0              NaN
#
#      mean compactness  mean concavity  mean concave points  mean symmetry  \
# 564           0.11590         0.24390              0.13890         0.1726
# 565           0.10340         0.14400                  NaN            NaN
# 566           0.10230         0.09251              0.05302         0.1590
# 567           0.27700         0.35140              0.15200            NaN
# 568           0.04362             NaN              0.00000         0.1587
#
#      mean fractal dimension  ...  worst smoothness  worst compactness  \
# 564                 0.05623  ...           0.14100            0.21130
# 565                 0.05533  ...           0.11660            0.19220
# 566                 0.05648  ...           0.11390            0.30940
# 567                 0.07016  ...           0.16500            0.86810
# 568                 0.05884  ...           0.08996            0.06444
#
#      worst concavity  worst concave points  worst symmetry  \
# 564           0.4107                0.2216          0.2060
# 565              NaN                   NaN          0.2572
# 566           0.3403                0.1418          0.2218
# 567           0.9387                   NaN          0.4087
# 568           0.0000                   NaN          0.2871
#
#      worst fractal dimension  target  false category  false category2  \
# 564                  0.07115     0.0               C                B
# 565                  0.06637     NaN             NaN                B
# 566                  0.07820     NaN             NaN              NaN
# 567                  0.12400     NaN             NaN                A
# 568                  0.07039     1.0               B                B
#
#      false category3
# 564                C
# 565              NaN
# 566                A
# 567                C
# 568                A
#
# [5 rows x 34 columns]

# %%
df_origin.describe()
# Out:
#        mean radius  mean texture  mean perimeter    mean area  \
# count   519.000000    496.000000      503.000000   517.000000
# mean     14.037709     19.325020       91.819364   655.173888
# std       3.531075      4.272731       23.994495   355.177714
# min       6.981000     10.720000       43.790000   143.500000
# 25%      11.625000     16.330000       75.015000   421.000000
# 50%      13.270000     18.880000       86.600000   551.100000
# 75%      15.740000     21.802500      103.650000   766.600000
# max      28.110000     39.280000      188.500000  2501.000000
#
#        mean smoothness  mean compactness  mean concavity  mean concave points  \
# count       513.000000        501.000000      520.000000           508.000000
# mean          0.096456          0.104642        0.087076             0.048444
# std           0.013846          0.053916        0.078027             0.037340
# min           0.062510          0.019380        0.000000             0.000000
# 25%           0.086680          0.064920        0.028885             0.020368
# 50%           0.095970          0.091820        0.059935             0.034190
# 75%           0.105400          0.130300        0.127725             0.074010
# max           0.163400          0.345400        0.426800             0.201200
#
#        mean symmetry  mean fractal dimension  ...  worst texture  \
# count     516.000000              499.000000  ...     508.000000
# mean        0.181156                0.062704  ...      25.726319
# std         0.027337                0.007201  ...       6.178125
# min         0.106000                0.049960  ...      12.490000
# 25%         0.161975                0.057510  ...      21.012500
# 50%         0.178800                0.061400  ...      25.475000
# 75%         0.196450                0.066165  ...      29.965000
# max         0.290600                0.097440  ...      49.540000
#
#        worst perimeter   worst area  worst smoothness  worst compactness  \
# count       515.000000   510.000000        506.000000         514.000000
# mean        107.001573   876.613137          0.132223           0.251265
# std          34.075052   571.362401          0.022970           0.154450
# min          50.410000   185.200000          0.071170           0.027290
# 25%          83.680000   513.300000          0.116600           0.147325
# 50%          97.170000   684.550000          0.131200           0.211650
# 75%         125.250000  1080.500000          0.146075           0.332550
# max         251.200000  4254.000000          0.222600           0.937900
#
#        worst concavity  worst concave points  worst symmetry  \
# count       513.000000            507.000000      494.000000
# mean          0.270044              0.115035        0.289970
# std           0.206169              0.065587        0.062584
# min           0.000000              0.000000        0.156500
# 25%           0.114400              0.064985        0.248725
# 50%           0.226000              0.099750        0.282650
# 75%           0.379100              0.163350        0.319525
# max           1.170000              0.291000        0.663800
#
#        worst fractal dimension      target
# count               514.000000  511.000000
# mean                  0.083813    0.632094
# std                   0.018116    0.482708
# min                   0.055040    0.000000
# 25%                   0.071010    0.000000
# 50%                   0.079960    1.000000
# 75%                   0.092075    1.000000
# max                   0.207500    1.000000
#
# [8 rows x 31 columns]

# %% [markdown]
# <section id="InitialResults">
#     <h3> 4.1. Initial informations </h3>
# </section>

# %%
eda_initial_informations(df_origin)
# Out:
# Number of rows: 569
# Number of columns: 34
# Index: RangeIndex(start=0, stop=569, step=1)

# %% [markdown]
# <section id="OverviewResults">
#     <h3> 4.2. Overview </h3>
# </section>

# %%
eda_summary_table(df_origin)
# Out:
#                          Variable Order  Number of total occurrences  \
# mean radius                           1                          569
# mean texture                          2                          569
# mean perimeter                        3                          569
# mean area                             4                          569
# mean smoothness                       5                          569
# mean compactness                      6                          569
# mean concavity                        7                          569
# mean concave points                   8                          569
# mean symmetry                         9                          569
# mean fractal dimension               10                          569
# radius error                         11                          569
# texture error                        12                          569
# perimeter error                      13                          569
# area error                           14                          569
# smoothness error                     15                          569
# compactness error                    16                          569
# concavity error                      17                          569
# concave points error                 18                          569
# symmetry error                       19                          569
# fractal dimension error              20                          569
# worst radius                         21                          569
# worst texture                        22                          569
# worst perimeter                      23                          569
# worst area                           24                          569
# worst smoothness                     25                          569
# worst compactness                    26                          569
# worst concavity                      27                          569
# worst concave points                 28                          569
# worst symmetry                       29                          569
# worst fractal dimension              30                          569
# target                               31                          569
# false category                       32                          569
# false category2                      33                          569
# false category3                      34                          569
#
#                          Number of no missing occurreces  Number of missing  \
# mean radius                                          519                 50
# mean texture                                         496                 73
# mean perimeter                                       503                 66
# mean area                                            517                 52
# mean smoothness                                      513                 56
# mean compactness                                     501                 68
# mean concavity                                       520                 49
# mean concave points                                  508                 61
# mean symmetry                                        516                 53
# mean fractal dimension                               499                 70
# radius error                                         508                 61
# texture error                                        509                 60
# perimeter error                                      497                 72
# area error                                           521                 48
# smoothness error                                     514                 55
# compactness error                                    499                 70
# concavity error                                      517                 52
# concave points error                                 519                 50
# symmetry error                                       513                 56
# fractal dimension error                              518                 51
# worst radius                                         500                 69
# worst texture                                        508                 61
# worst perimeter                                      515                 54
# worst area                                           510                 59
# worst smoothness                                     506                 63
# worst compactness                                    514                 55
# worst concavity                                      513                 56
# worst concave points                                 507                 62
# worst symmetry                                       494                 75
# worst fractal dimension                              514                 55
# target                                               511                 58
# false category                                       508                 61
# false category2                                      505                 64
# false category3                                      522                 47
#
#                          Percent of missing (%)  \
# mean radius                                   9
# mean texture                                 13
# mean perimeter                               12
# mean area                                     9
# mean smoothness                              10
# mean compactness                             12
# mean concavity                                9
# mean concave points                          11
# mean symmetry                                 9
# mean fractal dimension                       12
# radius error                                 11
# texture error                                11
# perimeter error                              13
# area error                                    8
# smoothness error                             10
# compactness error                            12
# concavity error                               9
# concave points error                          9
# symmetry error                               10
# fractal dimension error                       9
# worst radius                                 12
# worst texture                                11
# worst perimeter                               9
# worst area                                   10
# worst smoothness                             11
# worst compactness                            10
# worst concavity                              10
# worst concave points                         11
# worst symmetry                               13
# worst fractal dimension                      10
# target                                       10
# false category                               11
# false category2                              11
# false category3                               8
#
#                          Number of unique no missing occurrences   Format  \
# mean radius                                                  424  float64
# mean texture                                                 427  float64
# mean perimeter                                               472  float64
# mean area                                                    493  float64
# mean smoothness                                              431  float64
# mean compactness                                             474  float64
# mean concavity                                               491  float64
# mean concave points                                          486  float64
# mean symmetry                                                401  float64
# mean fractal dimension                                       448  float64
# radius error                                                 483  float64
# texture error                                                465  float64
# perimeter error                                              470  float64
# area error                                                   487  float64
# smoothness error                                             495  float64
# compactness error                                            478  float64
# concavity error                                              488  float64
# concave points error                                         468  float64
# symmetry error                                               455  float64
# fractal dimension error                                      499  float64
# worst radius                                                 417  float64
# worst texture                                                457  float64
# worst perimeter                                              475  float64
# worst area                                                   491  float64
# worst smoothness                                             378  float64
# worst compactness                                            482  float64
# worst concavity                                              488  float64
# worst concave points                                         446  float64
# worst symmetry                                               441  float64
# worst fractal dimension                                      493  float64
# target                                                         2  float64
# false category                                                 3   object
# false category2                                                3   object
# false category3                                                3   object
#
#                                 Type
# mean radius                  Numeric
# mean texture                 Numeric
# mean perimeter               Numeric
# mean area                    Numeric
# mean smoothness              Numeric
# mean compactness             Numeric
# mean concavity               Numeric
# mean concave points          Numeric
# mean symmetry                Numeric
# mean fractal dimension       Numeric
# radius error                 Numeric
# texture error                Numeric
# perimeter error              Numeric
# area error                   Numeric
# smoothness error             Numeric
# compactness error            Numeric
# concavity error              Numeric
# concave points error         Numeric
# symmetry error               Numeric
# fractal dimension error      Numeric
# worst radius                 Numeric
# worst texture                Numeric
# worst perimeter              Numeric
# worst area                   Numeric
# worst smoothness             Numeric
# worst compactness            Numeric
# worst concavity              Numeric
# worst concave points         Numeric
# worst symmetry               Numeric
# worst fractal dimension      Numeric
# target                       Numeric
# false category           Categorical
# false category2          Categorical
# false category3          Categorical

# %% [markdown]
# <section id="CategoricalDistributionsResults">
#     <h3> 4.3. Categorical variables distributions </h3>
# </section>

# %%
eda_categorical_variables_distributions(df_origin, df_origin, 33, 34)

# %%
eda_categorical_variables_distributions(X_test, X_validation, 30, 33)

# %% [markdown]
# <section id="NumericDistributionsResults">
#     <h3> 4.4. Numeric variables distributions </h3>
# </section>

# %%
eda_numeric_variables_distributions(df_origin, df_origin, 1, 3)

# %%
eda_numeric_variables_distributions(X_test, X_validation, 1, 7)

# %% [markdown]
# <section id="ProportionResults">
#     <h3> 4.5. Target proportion </h3>
# </section>

# %% [markdown]
# This function returns the distribution of the target variable, both in percentage and absolute values.

# %%
eda_target_distribution(y_origin, y_train, y_test, y_validation)

- Parameters:
    - original_dataframe:
    - train_dataframe: your train dataframe
    - test_dataframe: your test dataframe
    - validation_dataframe: your validation dataframe
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[179], line 3
#       1 eda_target_distribution(y_origin, y_train, y_test, y_validation)
# ----> 3 - Parametes
#
# NameError: name 'Parametes' is not defined

# %% [markdown]
# <section id="NumericVariablesCorrelationResults">
#     <h3> 4.6. Numeric variables correlation </h3>
# </section>

# %% [markdown]
# This function returns a heatmap that shows:
#
# 1. Correlation Scale:
#
# The heatmap uses colors to represent correlation values:
# - Blue: indicate **negative correlation**;
# - Red: indicate **positive correlation**;
# - Colors close to white: indicate little or **no correlation**.
#
# 2. Correlation Value (annotations in squares):
#
# Each square on the heatmap contains a number, which is the correlation value between the corresponding variables. This value ranges from -1 to 1.
# - 1: perfect **positive correlation** (when one variable increases, the other also increases in the same proportion).
# - -1: perfect **negative correlation** (when one variable increases, the other decreases in the same proportion).
# - 0: **absence** of linear correlation.
#
# 3. Patterns and relationships:
#
# Squares with darker colors indicate **stronger correlations**, while lighter colors indicate **weaker correlations**.
#
# - Parameters:
#     - df: the dataframe that you want to analyse

# %%
eda_variables_correlation(df_origin_missing_duplicate)

# %% [markdown]
# <section id="CategoricalOutliers">
#     <h3> 4.7. Categorical outliers </h3>
# </section>

# %% [markdown]
# This function returns frequencies that are much lower or much higher than others in the same category. Remember to interpret this result appropriately for your problem.
#
# - Parameters:
#     - df: the dataframe that you want to analyse

# %%
eda_categorical_outliers(df_origin)
# Out:
# Without outliers.

# %% [markdown]
# <section id="NumericOutliers">
#     <h3> 4.8. Numeric outliers </h3>
# </section>

# %% [markdown]
# This function returns values that are significantly lower or higher than the others in the same variable. Remember to interpret this result appropriately for your problem.
#
# - Parameters:
#     - df: the dataframe that you want to analyse

# %%
eda_categorical_outliers(df_origin)
# Out:
# Without outliers.
