# %% [markdown]
# # Exploratory data analysis

# %% [markdown]
# ## Table of contents
#
# 0. [Introduction](#Introduction)
# 1. [Import of packages](#Packages)
# 2. [Import of functions](#Functions)
# 3. [Import of data](#Data)
#     1. [Adjusting the dataframe to enhance analyses](#Adjusting)
#         1. [Category](#CategoryAdjusting)
#         2. [Duplicates](#DuplicatesAdjusting)
#         3. [Missing](#MissingAdjusting)
#     2. [Spliting the dataframe](#Spliting)
# 4. [Results](#EDAResults)
#     1. [Initial informations ](#InitialResults)
#     2. [Overview](#OverviewResults)
#     3. [Categorical Variables distributions](#CategoricalDistributionsResults)
#     4. [Numeric Variables distributions](#NumericDistributionsResults)
#     5. [Target proportion](#ProportionResults)

# %% [markdown]
# <section id="Introduction">
#     <h2> 0. Introduction </h2>
# </section>

# %% [markdown]
# This is a file with functions that aim to facilitate exploratory data analysis. As output, the functions provide graphs, metrics, and basic tables commonly used in the analysis process. Pay attention to the function parameters:
#
# - **df_origin**: single pandas dataframe;
#
# <br>
#
# - **X_train**: pandas train dataframe;
# - **X_test**: pandas test dataframe;
# - **X_validation**: pandas validation dataframe;
#
# <br>
#
# - **y_train**: train target;
# - **y_test**: test target;
# - **y_validation**: validation target;

# %% [markdown]
# ---

# %% [markdown]
# <section id="Packages">
#     <h2> 1. Import of packages </h2>
# </section>

# %%
#!pip install

# %%
from sklearn.datasets import load_breast_cancer

from fast_ml import eda
from fast_ml.model_development import train_valid_test_split
from fast_ml.utilities import reduce_memory_usage, display_all

import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import pickle # pickle
import pyarrow

# interative interface
import ipywidgets as widgets
from IPython.display import display

# %% [markdown]
# <section id="Functions">
#     <h2> 2. Import of Functions </h2>
# </section>

# %%
import os
print(os.getcwd())
# Out:
# /home/744ef240-a25d-4872-a66e-1d945ea1adf7/model_analysis/jupyter_notebooks/EDA

# %%
# %run "/home/744ef240-a25d-4872-a66e-1d945ea1adf7/model_analysis/jupyter_notebooks/EDA/model_analysis-eda-functions.ipynb"

# %% [markdown]
# <section id="Data">
#     <h2> 3. Import of data </h2>
# </section>

# %%
X_origin, y_origin = load_breast_cancer(return_X_y=True, as_frame=True)

# %%
y_dataframe = pd.DataFrame(y_origin, columns=['target'])

# %%
df_origin = pd.concat([X_origin, y_dataframe], axis=1)

# %%
df_origin
# Out:
#      mean radius  mean texture  mean perimeter  mean area  mean smoothness  \
# 0          17.99         10.38          122.80     1001.0          0.11840
# 1          20.57         17.77          132.90     1326.0          0.08474
# 2          19.69         21.25          130.00     1203.0          0.10960
# 3          11.42         20.38           77.58      386.1          0.14250
# 4          20.29         14.34          135.10     1297.0          0.10030
# ..           ...           ...             ...        ...              ...
# 564        21.56         22.39          142.00     1479.0          0.11100
# 565        20.13         28.25          131.20     1261.0          0.09780
# 566        16.60         28.08          108.30      858.1          0.08455
# 567        20.60         29.33          140.10     1265.0          0.11780
# 568         7.76         24.54           47.92      181.0          0.05263
#
#      mean compactness  mean concavity  mean concave points  mean symmetry  \
# 0             0.27760         0.30010              0.14710         0.2419
# 1             0.07864         0.08690              0.07017         0.1812
# 2             0.15990         0.19740              0.12790         0.2069
# 3             0.28390         0.24140              0.10520         0.2597
# 4             0.13280         0.19800              0.10430         0.1809
# ..                ...             ...                  ...            ...
# 564           0.11590         0.24390              0.13890         0.1726
# 565           0.10340         0.14400              0.09791         0.1752
# 566           0.10230         0.09251              0.05302         0.1590
# 567           0.27700         0.35140              0.15200         0.2397
# 568           0.04362         0.00000              0.00000         0.1587
#
#      mean fractal dimension  ...  worst texture  worst perimeter  worst area  \
# 0                   0.07871  ...          17.33           184.60      2019.0
# 1                   0.05667  ...          23.41           158.80      1956.0
# 2                   0.05999  ...          25.53           152.50      1709.0
# 3                   0.09744  ...          26.50            98.87       567.7
# 4                   0.05883  ...          16.67           152.20      1575.0
# ..                      ...  ...            ...              ...         ...
# 564                 0.05623  ...          26.40           166.10      2027.0
# 565                 0.05533  ...          38.25           155.00      1731.0
# 566                 0.05648  ...          34.12           126.70      1124.0
# 567                 0.07016  ...          39.42           184.60      1821.0
# 568                 0.05884  ...          30.37            59.16       268.6
#
#      worst smoothness  worst compactness  worst concavity  \
# 0             0.16220            0.66560           0.7119
# 1             0.12380            0.18660           0.2416
# 2             0.14440            0.42450           0.4504
# 3             0.20980            0.86630           0.6869
# 4             0.13740            0.20500           0.4000
# ..                ...                ...              ...
# 564           0.14100            0.21130           0.4107
# 565           0.11660            0.19220           0.3215
# 566           0.11390            0.30940           0.3403
# 567           0.16500            0.86810           0.9387
# 568           0.08996            0.06444           0.0000
#
#      worst concave points  worst symmetry  worst fractal dimension  target
# 0                  0.2654          0.4601                  0.11890       0
# 1                  0.1860          0.2750                  0.08902       0
# 2                  0.2430          0.3613                  0.08758       0
# 3                  0.2575          0.6638                  0.17300       0
# 4                  0.1625          0.2364                  0.07678       0
# ..                    ...             ...                      ...     ...
# 564                0.2216          0.2060                  0.07115       0
# 565                0.1628          0.2572                  0.06637       0
# 566                0.1418          0.2218                  0.07820       0
# 567                0.2650          0.4087                  0.12400       0
# 568                0.0000          0.2871                  0.07039       1
#
# [569 rows x 31 columns]

# %% [markdown]
# <section id="Adjusting">
#     <h3> 3.1. Adjusting the dataframe to enhance analyses </h3>
# </section>

# %% [markdown]
# <section id="CategoryAdjusting">
#     <h4> 3.1.1. Category </h4>
# </section>

# %%
categories = ['A', 'B', 'C']

df_origin['false category'] = np.random.choice(categories, size=len(df_origin))
df_origin['false category2'] = np.random.choice(categories, size=len(df_origin))
df_origin['false category3'] = np.random.choice(categories, size=len(df_origin))

# %%
df_origin
# Out:
#      mean radius  mean texture  mean perimeter  mean area  mean smoothness  \
# 0          17.99         10.38          122.80     1001.0          0.11840
# 1          20.57         17.77          132.90     1326.0          0.08474
# 2          19.69         21.25          130.00     1203.0          0.10960
# 3          11.42         20.38           77.58      386.1          0.14250
# 4          20.29         14.34          135.10     1297.0          0.10030
# ..           ...           ...             ...        ...              ...
# 564        21.56         22.39          142.00     1479.0          0.11100
# 565        20.13         28.25          131.20     1261.0          0.09780
# 566        16.60         28.08          108.30      858.1          0.08455
# 567        20.60         29.33          140.10     1265.0          0.11780
# 568         7.76         24.54           47.92      181.0          0.05263
#
#      mean compactness  mean concavity  mean concave points  mean symmetry  \
# 0             0.27760         0.30010              0.14710         0.2419
# 1             0.07864         0.08690              0.07017         0.1812
# 2             0.15990         0.19740              0.12790         0.2069
# 3             0.28390         0.24140              0.10520         0.2597
# 4             0.13280         0.19800              0.10430         0.1809
# ..                ...             ...                  ...            ...
# 564           0.11590         0.24390              0.13890         0.1726
# 565           0.10340         0.14400              0.09791         0.1752
# 566           0.10230         0.09251              0.05302         0.1590
# 567           0.27700         0.35140              0.15200         0.2397
# 568           0.04362         0.00000              0.00000         0.1587
#
#      mean fractal dimension  ...  worst smoothness  worst compactness  \
# 0                   0.07871  ...           0.16220            0.66560
# 1                   0.05667  ...           0.12380            0.18660
# 2                   0.05999  ...           0.14440            0.42450
# 3                   0.09744  ...           0.20980            0.86630
# 4                   0.05883  ...           0.13740            0.20500
# ..                      ...  ...               ...                ...
# 564                 0.05623  ...           0.14100            0.21130
# 565                 0.05533  ...           0.11660            0.19220
# 566                 0.05648  ...           0.11390            0.30940
# 567                 0.07016  ...           0.16500            0.86810
# 568                 0.05884  ...           0.08996            0.06444
#
#      worst concavity  worst concave points  worst symmetry  \
# 0             0.7119                0.2654          0.4601
# 1             0.2416                0.1860          0.2750
# 2             0.4504                0.2430          0.3613
# 3             0.6869                0.2575          0.6638
# 4             0.4000                0.1625          0.2364
# ..               ...                   ...             ...
# 564           0.4107                0.2216          0.2060
# 565           0.3215                0.1628          0.2572
# 566           0.3403                0.1418          0.2218
# 567           0.9387                0.2650          0.4087
# 568           0.0000                0.0000          0.2871
#
#      worst fractal dimension  target  false category  false category2  \
# 0                    0.11890       0               B                B
# 1                    0.08902       0               B                A
# 2                    0.08758       0               C                A
# 3                    0.17300       0               C                A
# 4                    0.07678       0               A                A
# ..                       ...     ...             ...              ...
# 564                  0.07115       0               C                A
# 565                  0.06637       0               A                C
# 566                  0.07820       0               A                B
# 567                  0.12400       0               B                B
# 568                  0.07039       1               A                A
#
#      false category3
# 0                  A
# 1                  B
# 2                  A
# 3                  C
# 4                  B
# ..               ...
# 564                B
# 565                C
# 566                A
# 567                C
# 568                B
#
# [569 rows x 34 columns]

# %% [markdown]
# <section id="MissingAdjusting">
#     <h4> 3.1.2. Missing </h4>
# </section>

# %%
num_rows, num_columns = df_origin.shape
missing_percent = 0.11
missing_num = int(num_rows * num_columns * missing_percent)

affected_rows = np.random.randint(0, num_rows, missing_num)
affected_columns = np.random.randint(0, num_columns, missing_num)

for row, column in zip(affected_rows, affected_columns):
    df_origin.iat[row, column] = np.nan

# %%
df_origin_missing = df_origin[df_origin['target'].notna()]

# %%
df_origin_missing
# Out:
#      mean radius  mean texture  mean perimeter  mean area  mean smoothness  \
# 0          17.99         10.38          122.80     1001.0          0.11840
# 1          20.57         17.77          132.90     1326.0          0.08474
# 2          19.69         21.25          130.00     1203.0          0.10960
# 3          11.42         20.38           77.58      386.1          0.14250
# 4          20.29         14.34             NaN     1297.0          0.10030
# ..           ...           ...             ...        ...              ...
# 564        21.56         22.39          142.00     1479.0          0.11100
# 565        20.13         28.25          131.20     1261.0          0.09780
# 566        16.60         28.08          108.30      858.1          0.08455
# 567        20.60         29.33          140.10     1265.0          0.11780
# 568         7.76         24.54           47.92      181.0          0.05263
#
#      mean compactness  mean concavity  mean concave points  mean symmetry  \
# 0             0.27760         0.30010              0.14710         0.2419
# 1             0.07864         0.08690              0.07017         0.1812
# 2             0.15990             NaN              0.12790         0.2069
# 3             0.28390         0.24140              0.10520         0.2597
# 4             0.13280         0.19800              0.10430            NaN
# ..                ...             ...                  ...            ...
# 564           0.11590         0.24390              0.13890         0.1726
# 565           0.10340         0.14400              0.09791         0.1752
# 566           0.10230         0.09251              0.05302         0.1590
# 567           0.27700         0.35140              0.15200         0.2397
# 568           0.04362             NaN              0.00000         0.1587
#
#      mean fractal dimension  ...  worst smoothness  worst compactness  \
# 0                   0.07871  ...           0.16220            0.66560
# 1                   0.05667  ...           0.12380            0.18660
# 2                   0.05999  ...           0.14440            0.42450
# 3                   0.09744  ...           0.20980            0.86630
# 4                   0.05883  ...           0.13740            0.20500
# ..                      ...  ...               ...                ...
# 564                 0.05623  ...           0.14100            0.21130
# 565                 0.05533  ...           0.11660            0.19220
# 566                 0.05648  ...           0.11390            0.30940
# 567                 0.07016  ...           0.16500            0.86810
# 568                 0.05884  ...           0.08996            0.06444
#
#      worst concavity  worst concave points  worst symmetry  \
# 0             0.7119                0.2654          0.4601
# 1             0.2416                0.1860          0.2750
# 2             0.4504                0.2430          0.3613
# 3             0.6869                0.2575          0.6638
# 4             0.4000                   NaN          0.2364
# ..               ...                   ...             ...
# 564           0.4107                0.2216          0.2060
# 565           0.3215                0.1628          0.2572
# 566           0.3403                0.1418          0.2218
# 567           0.9387                0.2650          0.4087
# 568           0.0000                0.0000          0.2871
#
#      worst fractal dimension  target  false category  false category2  \
# 0                    0.11890     0.0             NaN                B
# 1                    0.08902     0.0               B              NaN
# 2                    0.08758     0.0               C                A
# 3                    0.17300     0.0               C                A
# 4                    0.07678     0.0               A                A
# ..                       ...     ...             ...              ...
# 564                  0.07115     0.0               C                A
# 565                  0.06637     0.0               A                C
# 566                  0.07820     0.0               A                B
# 567                  0.12400     0.0               B                B
# 568                  0.07039     1.0               A              NaN
#
#      false category3
# 0                  A
# 1                  B
# 2                  A
# 3                NaN
# 4                  B
# ..               ...
# 564                B
# 565                C
# 566              NaN
# 567                C
# 568                B
#
# [512 rows x 34 columns]

# %% [markdown]
# <section id="DuplicatesAdjusting">
#     <h4> 3.1.3. Duplicates </h4>
# </section>

# %%
num_duplicates = 555

random_index = np.random.choice(df_origin_missing.index, num_duplicates, replace=True)

duplicates = df_origin_missing.loc[random_index]

df_origin_missing_duplicate = pd.concat([df_origin_missing, duplicates])

df_origin_missing_duplicate.reset_index(drop=True, inplace=True)

# %%
df_origin_missing_duplicate
# Out:
#       mean radius  mean texture  mean perimeter  mean area  mean smoothness  \
# 0          17.990         10.38          122.80     1001.0          0.11840
# 1          20.570         17.77          132.90     1326.0          0.08474
# 2          19.690         21.25          130.00     1203.0          0.10960
# 3          11.420         20.38           77.58      386.1          0.14250
# 4          20.290         14.34             NaN     1297.0          0.10030
# ...           ...           ...             ...        ...              ...
# 1062       14.800           NaN             NaN      674.8          0.09179
# 1063          NaN         18.90           76.66        NaN              NaN
# 1064       11.080         18.83           73.30      361.6          0.12160
# 1065       11.660         17.07           73.70      421.0          0.07561
# 1066        9.668         18.10           61.06      286.3          0.08311
#
#       mean compactness  mean concavity  mean concave points  mean symmetry  \
# 0              0.27760        0.300100             0.147100         0.2419
# 1              0.07864        0.086900             0.070170         0.1812
# 2              0.15990             NaN             0.127900         0.2069
# 3              0.28390        0.241400             0.105200         0.2597
# 4              0.13280        0.198000             0.104300            NaN
# ...                ...             ...                  ...            ...
# 1062           0.08890        0.040690             0.022600         0.1893
# 1063           0.05794        0.007510             0.008488         0.1555
# 1064           0.21540        0.168900             0.063670         0.2196
# 1065           0.03630        0.008306             0.011620         0.1671
# 1066           0.05428        0.014790                  NaN         0.1680
#
#       mean fractal dimension  ...  worst smoothness  worst compactness  \
# 0                    0.07871  ...           0.16220            0.66560
# 1                    0.05667  ...           0.12380            0.18660
# 2                    0.05999  ...           0.14440            0.42450
# 3                    0.09744  ...           0.20980            0.86630
# 4                    0.05883  ...           0.13740            0.20500
# ...                      ...  ...               ...                ...
# 1062                 0.05886  ...           0.12260            0.18810
# 1063                     NaN  ...           0.12890            0.13520
# 1064                 0.07950  ...           0.21840            0.93790
# 1065                 0.05731  ...           0.09958            0.06476
# 1066                 0.06412  ...           0.13880            0.12550
#
#       worst concavity  worst concave points  worst symmetry  \
# 0             0.71190               0.26540          0.4601
# 1             0.24160               0.18600          0.2750
# 2             0.45040               0.24300          0.3613
# 3             0.68690               0.25750          0.6638
# 4             0.40000                   NaN          0.2364
# ...               ...                   ...             ...
# 1062          0.20600               0.08308          0.3600
# 1063              NaN               0.05093          0.2880
# 1064          0.84020               0.25240          0.4154
# 1065          0.03046               0.04262          0.2731
# 1066          0.06409               0.02500          0.3057
#
#       worst fractal dimension  target  false category  false category2  \
# 0                     0.11890     0.0             NaN                B
# 1                     0.08902     0.0               B              NaN
# 2                     0.08758     0.0               C                A
# 3                     0.17300     0.0               C                A
# 4                     0.07678     0.0               A                A
# ...                       ...     ...             ...              ...
# 1062                  0.07285     1.0               A                B
# 1063                  0.08083     1.0             NaN              NaN
# 1064                  0.14030     0.0               B                A
# 1065                      NaN     1.0             NaN                C
# 1066                  0.07875     1.0               C                A
#
#       false category3
# 0                   A
# 1                   B
# 2                   A
# 3                 NaN
# 4                   B
# ...               ...
# 1062                A
# 1063              NaN
# 1064                A
# 1065                C
# 1066                B
#
# [1067 rows x 34 columns]

# %% [markdown]
# <section id="Spliting">
#     <h3> 3.2. Spliting the dataframe </h3>
# </section>

# %%
X_train, y_train, X_validation, y_validation, X_test, y_test = train_valid_test_split(
                                                        df_origin_missing_duplicate,
                                                        target = 'target',
                                                        train_size=0.8,
                                                        valid_size=0.1,
                                                        test_size=0.1)

# %% [markdown]
# ---

# %% [markdown]
# <section id="EDAResults">
#     <h2> 4. Results </h2>
# </section>

# %% [markdown]
# Note that the `df_origin` has more columns than `X_<>`, which corresponds to the target variable.

# %%
df_origin.head(5)
# Out:
#    mean radius  mean texture  mean perimeter  mean area  mean smoothness  \
# 0        17.99         10.38          122.80     1001.0          0.11840
# 1        20.57         17.77          132.90     1326.0          0.08474
# 2        19.69         21.25          130.00     1203.0          0.10960
# 3        11.42         20.38           77.58      386.1          0.14250
# 4        20.29         14.34             NaN     1297.0          0.10030
#
#    mean compactness  mean concavity  mean concave points  mean symmetry  \
# 0           0.27760          0.3001              0.14710         0.2419
# 1           0.07864          0.0869              0.07017         0.1812
# 2           0.15990             NaN              0.12790         0.2069
# 3           0.28390          0.2414              0.10520         0.2597
# 4           0.13280          0.1980              0.10430            NaN
#
#    mean fractal dimension  ...  worst smoothness  worst compactness  \
# 0                 0.07871  ...            0.1622             0.6656
# 1                 0.05667  ...            0.1238             0.1866
# 2                 0.05999  ...            0.1444             0.4245
# 3                 0.09744  ...            0.2098             0.8663
# 4                 0.05883  ...            0.1374             0.2050
#
#    worst concavity  worst concave points  worst symmetry  \
# 0           0.7119                0.2654          0.4601
# 1           0.2416                0.1860          0.2750
# 2           0.4504                0.2430          0.3613
# 3           0.6869                0.2575          0.6638
# 4           0.4000                   NaN          0.2364
#
#    worst fractal dimension  target  false category  false category2  \
# 0                  0.11890     0.0             NaN                B
# 1                  0.08902     0.0               B              NaN
# 2                  0.08758     0.0               C                A
# 3                  0.17300     0.0               C                A
# 4                  0.07678     0.0               A                A
#
#    false category3
# 0                A
# 1                B
# 2                A
# 3              NaN
# 4                B
#
# [5 rows x 34 columns]

# %%
df_origin.tail(5)
# Out:
#      mean radius  mean texture  mean perimeter  mean area  mean smoothness  \
# 564        21.56         22.39          142.00     1479.0          0.11100
# 565        20.13         28.25          131.20     1261.0          0.09780
# 566        16.60         28.08          108.30      858.1          0.08455
# 567        20.60         29.33          140.10     1265.0          0.11780
# 568         7.76         24.54           47.92      181.0          0.05263
#
#      mean compactness  mean concavity  mean concave points  mean symmetry  \
# 564           0.11590         0.24390              0.13890         0.1726
# 565           0.10340         0.14400              0.09791         0.1752
# 566           0.10230         0.09251              0.05302         0.1590
# 567           0.27700         0.35140              0.15200         0.2397
# 568           0.04362             NaN              0.00000         0.1587
#
#      mean fractal dimension  ...  worst smoothness  worst compactness  \
# 564                 0.05623  ...           0.14100            0.21130
# 565                 0.05533  ...           0.11660            0.19220
# 566                 0.05648  ...           0.11390            0.30940
# 567                 0.07016  ...           0.16500            0.86810
# 568                 0.05884  ...           0.08996            0.06444
#
#      worst concavity  worst concave points  worst symmetry  \
# 564           0.4107                0.2216          0.2060
# 565           0.3215                0.1628          0.2572
# 566           0.3403                0.1418          0.2218
# 567           0.9387                0.2650          0.4087
# 568           0.0000                0.0000          0.2871
#
#      worst fractal dimension  target  false category  false category2  \
# 564                  0.07115     0.0               C                A
# 565                  0.06637     0.0               A                C
# 566                  0.07820     0.0               A                B
# 567                  0.12400     0.0               B                B
# 568                  0.07039     1.0               A              NaN
#
#      false category3
# 564                B
# 565                C
# 566              NaN
# 567                C
# 568                B
#
# [5 rows x 34 columns]

# %%
df_origin.describe()
# Out:
#        mean radius  mean texture  mean perimeter    mean area  \
# count   520.000000    515.000000      507.000000   510.000000
# mean     14.134390     19.288524       92.152189   662.969216
# std       3.527862      4.289226       24.218940   357.467538
# min       6.981000     10.380000       43.790000   143.500000
# 25%      11.667500     16.170000       75.100000   421.475000
# 50%      13.435000     18.890000       86.490000   557.650000
# 75%      15.892500     21.805000      104.900000   790.575000
# max      27.420000     39.280000      186.900000  2501.000000
#
#        mean smoothness  mean compactness  mean concavity  mean concave points  \
# count       522.000000        503.000000      525.000000           502.000000
# mean          0.096493          0.105944        0.087290             0.048417
# std           0.014192          0.053559        0.078082             0.038753
# min           0.052630          0.019380        0.000000             0.000000
# 25%           0.086635          0.066160        0.029560             0.020103
# 50%           0.096425          0.095090        0.060150             0.033455
# 75%           0.105400          0.130800        0.122600             0.072710
# max           0.163400          0.345400        0.426800             0.201200
#
#        mean symmetry  mean fractal dimension  ...  worst texture  \
# count     520.000000              509.000000  ...     504.000000
# mean        0.181202                0.062689  ...      25.743790
# std         0.027685                0.007011  ...       6.263951
# min         0.106000                0.049960  ...      12.020000
# 25%         0.161975                0.057640  ...      21.095000
# 50%         0.178400                0.061320  ...      25.470000
# 75%         0.195975                0.066120  ...      29.965000
# max         0.304000                0.097440  ...      49.540000
#
#        worst perimeter   worst area  worst smoothness  worst compactness  \
# count       519.000000   504.000000        500.000000         502.000000
# mean        108.128998   890.713492          0.132375           0.256350
# std          33.739866   583.229625          0.022922           0.161382
# min          50.410000   185.200000          0.071170           0.027290
# 25%          84.480000   516.475000          0.116600           0.147325
# 50%          98.270000   687.100000          0.131400           0.211450
# 75%         127.100000  1096.750000          0.146000           0.341600
# max         251.200000  4254.000000          0.222600           1.058000
#
#        worst concavity  worst concave points  worst symmetry  \
# count       511.000000            499.000000      511.000000
# mean          0.274688              0.114969        0.290072
# std           0.211743              0.065877        0.062262
# min           0.000000              0.000000        0.156500
# 25%           0.116750              0.064985        0.250300
# 50%           0.228200              0.098610        0.282200
# 75%           0.385700              0.164800        0.317150
# max           1.252000              0.290300        0.663800
#
#        worst fractal dimension      target
# count               520.000000  512.000000
# mean                  0.084282    0.630859
# std                   0.018306    0.483044
# min                   0.055040    0.000000
# 25%                   0.071468    0.000000
# 50%                   0.080420    1.000000
# 75%                   0.092095    1.000000
# max                   0.207500    1.000000
#
# [8 rows x 31 columns]

# %% [markdown]
# <section id="InitialResults">
#     <h3> 4.1. Initial informations </h3>
# </section>

# %%
eda_initial_informations(df_origin)
# Out:
# Number of rows: 569
# Number of columns: 34
# Index: RangeIndex(start=0, stop=569, step=1)

# %% [markdown]
# <section id="OverviewResults">
#     <h3> 4.2. Overview </h3>
# </section>

# %%
eda_summary_table(df_origin)
# Out:
#                          Variable Order  Number of total occurrences  \
# mean radius                           1                          569
# mean texture                          2                          569
# mean perimeter                        3                          569
# mean area                             4                          569
# mean smoothness                       5                          569
# mean compactness                      6                          569
# mean concavity                        7                          569
# mean concave points                   8                          569
# mean symmetry                         9                          569
# mean fractal dimension               10                          569
# radius error                         11                          569
# texture error                        12                          569
# perimeter error                      13                          569
# area error                           14                          569
# smoothness error                     15                          569
# compactness error                    16                          569
# concavity error                      17                          569
# concave points error                 18                          569
# symmetry error                       19                          569
# fractal dimension error              20                          569
# worst radius                         21                          569
# worst texture                        22                          569
# worst perimeter                      23                          569
# worst area                           24                          569
# worst smoothness                     25                          569
# worst compactness                    26                          569
# worst concavity                      27                          569
# worst concave points                 28                          569
# worst symmetry                       29                          569
# worst fractal dimension              30                          569
# target                               31                          569
# false category                       32                          569
# false category2                      33                          569
# false category3                      34                          569
#
#                          Number of no missing occurreces  Number of missing  \
# mean radius                                          520                 49
# mean texture                                         515                 54
# mean perimeter                                       507                 62
# mean area                                            510                 59
# mean smoothness                                      522                 47
# mean compactness                                     503                 66
# mean concavity                                       525                 44
# mean concave points                                  502                 67
# mean symmetry                                        520                 49
# mean fractal dimension                               509                 60
# radius error                                         514                 55
# texture error                                        504                 65
# perimeter error                                      504                 65
# area error                                           514                 55
# smoothness error                                     512                 57
# compactness error                                    503                 66
# concavity error                                      513                 56
# concave points error                                 504                 65
# symmetry error                                       506                 63
# fractal dimension error                              501                 68
# worst radius                                         515                 54
# worst texture                                        504                 65
# worst perimeter                                      519                 50
# worst area                                           504                 65
# worst smoothness                                     500                 69
# worst compactness                                    502                 67
# worst concavity                                      511                 58
# worst concave points                                 499                 70
# worst symmetry                                       511                 58
# worst fractal dimension                              520                 49
# target                                               512                 57
# false category                                       509                 60
# false category2                                      497                 72
# false category3                                      512                 57
#
#                          Percent of missing (%)  \
# mean radius                                   9
# mean texture                                  9
# mean perimeter                               11
# mean area                                    10
# mean smoothness                               8
# mean compactness                             12
# mean concavity                                8
# mean concave points                          12
# mean symmetry                                 9
# mean fractal dimension                       11
# radius error                                 10
# texture error                                11
# perimeter error                              11
# area error                                   10
# smoothness error                             10
# compactness error                            12
# concavity error                              10
# concave points error                         11
# symmetry error                               11
# fractal dimension error                      12
# worst radius                                  9
# worst texture                                11
# worst perimeter                               9
# worst area                                   11
# worst smoothness                             12
# worst compactness                            12
# worst concavity                              10
# worst concave points                         12
# worst symmetry                               10
# worst fractal dimension                       9
# target                                       10
# false category                               11
# false category2                              13
# false category3                              10
#
#                          Number of unique no missing occurrences   Format  \
# mean radius                                                  431  float64
# mean texture                                                 440  float64
# mean perimeter                                               469  float64
# mean area                                                    485  float64
# mean smoothness                                              441  float64
# mean compactness                                             477  float64
# mean concavity                                               501  float64
# mean concave points                                          478  float64
# mean symmetry                                                399  float64
# mean fractal dimension                                       452  float64
# radius error                                                 491  float64
# texture error                                                462  float64
# perimeter error                                              475  float64
# area error                                                   477  float64
# smoothness error                                             496  float64
# compactness error                                            484  float64
# concavity error                                              485  float64
# concave points error                                         453  float64
# symmetry error                                               451  float64
# fractal dimension error                                      482  float64
# worst radius                                                 425  float64
# worst texture                                                466  float64
# worst perimeter                                              472  float64
# worst area                                                   486  float64
# worst smoothness                                             372  float64
# worst compactness                                            469  float64
# worst concavity                                              485  float64
# worst concave points                                         440  float64
# worst symmetry                                               461  float64
# worst fractal dimension                                      489  float64
# target                                                         2  float64
# false category                                                 3   object
# false category2                                                3   object
# false category3                                                3   object
#
#                                 Type
# mean radius                  Numeric
# mean texture                 Numeric
# mean perimeter               Numeric
# mean area                    Numeric
# mean smoothness              Numeric
# mean compactness             Numeric
# mean concavity               Numeric
# mean concave points          Numeric
# mean symmetry                Numeric
# mean fractal dimension       Numeric
# radius error                 Numeric
# texture error                Numeric
# perimeter error              Numeric
# area error                   Numeric
# smoothness error             Numeric
# compactness error            Numeric
# concavity error              Numeric
# concave points error         Numeric
# symmetry error               Numeric
# fractal dimension error      Numeric
# worst radius                 Numeric
# worst texture                Numeric
# worst perimeter              Numeric
# worst area                   Numeric
# worst smoothness             Numeric
# worst compactness            Numeric
# worst concavity              Numeric
# worst concave points         Numeric
# worst symmetry               Numeric
# worst fractal dimension      Numeric
# target                       Numeric
# false category           Categorical
# false category2          Categorical
# false category3          Categorical

# %% [markdown]
# <section id="CategoricalDistributionsResults">
#     <h3> 4.3. Categorical Variables Distributions </h3>
# </section>

# %%
eda_categorical_variables_distributions(df_origin, df_origin, 33, 34)

# %%
eda_categorical_variables_distributions(X_test, X_validation, 30, 33)

# %% [markdown]
# <section id="NumericDistributionsResults">
#     <h3> 4.4. Numeric Variables Distributions </h3>
# </section>

# %%
eda_numeric_variables_distributions(df_origin, df_origin, 1, 3)

# %%
eda_numeric_variables_distributions(X_test, X_validation, 1, 7)

# %% [markdown]
# <section id="ProportionResults">
#     <h3> 4.5. Target proportion </h3>
# </section>

# %%
eda_target_distribution(y_origin, y_train, y_test, y_validation)

# %% [markdown]
# <section id="VariablesCorrelationResults">
#     <h3> 4.6. Variables Correlation </h3>
# </section>

# %%
eda_variables_correlation(df_origin_missing_duplicate)
