# %% [markdown]
# # Exploratory data analysis

# %% [markdown]
# ## Table of contents
#
# 0. [Introduction](#Introduction)
# 1. [Import of packages](#Packages)
# 2. [Import of data](#Data)
#     1. [Adjusting the dataframe to enhance analyses](#Adjusting)
#     2. [Spliting the dataframe](#Spliting)
#     3. [Saving of the data](#Saving)
# 3. [Functions definitions](#Functions)
#     1. [Initial informations ](#Initial)
#     2. [Overview](#Overview)
#     3. [Variables distributions](#DistributionsFunction)
#     4. [Target proportion](#ProportionFunction)
# 4. [Exploratory Data Analysis Results](#EDAResults)
#     1. [Initial informations ](#InitialResults)
#     2. [Overview](#OverviewResults)
#     3. [Variables distributions](#DistributionsResults)
#     4. [Target proportion](#ProportionResults)

# %% [markdown]
# <section id="Introduction">
#     <h2> 0. Introduction </h2>
# </section>

# %% [markdown]
# This is a file with functions that aim to facilitate exploratory data analysis. As output, the functions provide graphs, metrics, and basic tables commonly used in the analysis process. Pay attention to the function parameters:
#
# - **df_origin**: single pandas dataframe;
#
# <br>
#
# - **X_train**: pandas train dataframe;
# - **X_test**: pandas test dataframe;
# - **X_validation**: pandas validation dataframe;
#
# <br>
#
# - **y_train**: train target;
# - **y_test**: test target;
# - **y_validation**: validation target;

# %% [markdown]
# ---

# %% [markdown]
# <section id="Packages">
#     <h2> 1. Import of packages </h2>
# </section>

# %%
#!pip install

# %%
from sklearn.datasets import load_breast_cancer

from fast_ml import eda
from fast_ml.model_development import train_valid_test_split
from fast_ml.utilities import reduce_memory_usage, display_all

import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import pickle # pickle
import pyarrow

# interative interface
import ipywidgets as widgets
from IPython.display import display

# %% [markdown]
# <section id="Data">
#     <h2> 2. Import of data </h2>
# </section>

# %%
X_origin, y_origin = load_breast_cancer(return_X_y=True, as_frame=True)

# %%
y_dataframe = pd.DataFrame(y_origin, columns=['target'])

# %%
df_origin = pd.concat([X_origin, y_dataframe], axis=1)

# %%
df_origin
# Out:
#      mean radius  mean texture  mean perimeter  mean area  mean smoothness  \
# 0          17.99         10.38          122.80     1001.0          0.11840
# 1          20.57         17.77          132.90     1326.0          0.08474
# 2          19.69         21.25          130.00     1203.0          0.10960
# 3          11.42         20.38           77.58      386.1          0.14250
# 4          20.29         14.34          135.10     1297.0          0.10030
# ..           ...           ...             ...        ...              ...
# 564        21.56         22.39          142.00     1479.0          0.11100
# 565        20.13         28.25          131.20     1261.0          0.09780
# 566        16.60         28.08          108.30      858.1          0.08455
# 567        20.60         29.33          140.10     1265.0          0.11780
# 568         7.76         24.54           47.92      181.0          0.05263
#
#      mean compactness  mean concavity  mean concave points  mean symmetry  \
# 0             0.27760         0.30010              0.14710         0.2419
# 1             0.07864         0.08690              0.07017         0.1812
# 2             0.15990         0.19740              0.12790         0.2069
# 3             0.28390         0.24140              0.10520         0.2597
# 4             0.13280         0.19800              0.10430         0.1809
# ..                ...             ...                  ...            ...
# 564           0.11590         0.24390              0.13890         0.1726
# 565           0.10340         0.14400              0.09791         0.1752
# 566           0.10230         0.09251              0.05302         0.1590
# 567           0.27700         0.35140              0.15200         0.2397
# 568           0.04362         0.00000              0.00000         0.1587
#
#      mean fractal dimension  ...  worst texture  worst perimeter  worst area  \
# 0                   0.07871  ...          17.33           184.60      2019.0
# 1                   0.05667  ...          23.41           158.80      1956.0
# 2                   0.05999  ...          25.53           152.50      1709.0
# 3                   0.09744  ...          26.50            98.87       567.7
# 4                   0.05883  ...          16.67           152.20      1575.0
# ..                      ...  ...            ...              ...         ...
# 564                 0.05623  ...          26.40           166.10      2027.0
# 565                 0.05533  ...          38.25           155.00      1731.0
# 566                 0.05648  ...          34.12           126.70      1124.0
# 567                 0.07016  ...          39.42           184.60      1821.0
# 568                 0.05884  ...          30.37            59.16       268.6
#
#      worst smoothness  worst compactness  worst concavity  \
# 0             0.16220            0.66560           0.7119
# 1             0.12380            0.18660           0.2416
# 2             0.14440            0.42450           0.4504
# 3             0.20980            0.86630           0.6869
# 4             0.13740            0.20500           0.4000
# ..                ...                ...              ...
# 564           0.14100            0.21130           0.4107
# 565           0.11660            0.19220           0.3215
# 566           0.11390            0.30940           0.3403
# 567           0.16500            0.86810           0.9387
# 568           0.08996            0.06444           0.0000
#
#      worst concave points  worst symmetry  worst fractal dimension  target
# 0                  0.2654          0.4601                  0.11890       0
# 1                  0.1860          0.2750                  0.08902       0
# 2                  0.2430          0.3613                  0.08758       0
# 3                  0.2575          0.6638                  0.17300       0
# 4                  0.1625          0.2364                  0.07678       0
# ..                    ...             ...                      ...     ...
# 564                0.2216          0.2060                  0.07115       0
# 565                0.1628          0.2572                  0.06637       0
# 566                0.1418          0.2218                  0.07820       0
# 567                0.2650          0.4087                  0.12400       0
# 568                0.0000          0.2871                  0.07039       1
#
# [569 rows x 31 columns]

# %% [markdown]
# <section id="Adjusting">
#     <h3> 2.1. Adjusting the dataframe to enhance analyses </h3>
# </section>

# %% [markdown]
# <section id="MissingAdjusting">
#     <h4> 2.1.1. Missing </h4>
# </section>

# %%
num_rows, num_columns = df_origin.shape
missing_percent = 0.11
missing_num = int(num_rows * num_columns * missing_percent)

affected_rows = np.random.randint(0, num_rows, missing_num)
affected_columns = np.random.randint(0, num_columns, missing_num)

for row, column in zip(affected_rows, affected_columns):
    df_origin.iat[row, column] = np.nan

# %%
df_origin_missing = df_origin[df_origin['target'].notna()]

# %%
df_origin_missing
# Out:
#      mean radius  mean texture  mean perimeter  mean area  mean smoothness  \
# 0          17.99         10.38          122.80        NaN          0.11840
# 1            NaN         17.77          132.90     1326.0          0.08474
# 2          19.69         21.25          130.00     1203.0          0.10960
# 3          11.42         20.38           77.58      386.1          0.14250
# 4          20.29         14.34          135.10     1297.0          0.10030
# ..           ...           ...             ...        ...              ...
# 564        21.56           NaN          142.00     1479.0          0.11100
# 565        20.13         28.25          131.20     1261.0          0.09780
# 566          NaN         28.08          108.30      858.1          0.08455
# 567        20.60         29.33          140.10     1265.0          0.11780
# 568         7.76         24.54           47.92      181.0          0.05263
#
#      mean compactness  mean concavity  mean concave points  mean symmetry  \
# 0             0.27760         0.30010              0.14710         0.2419
# 1             0.07864         0.08690              0.07017         0.1812
# 2             0.15990         0.19740              0.12790         0.2069
# 3             0.28390         0.24140              0.10520         0.2597
# 4             0.13280         0.19800              0.10430         0.1809
# ..                ...             ...                  ...            ...
# 564           0.11590         0.24390              0.13890         0.1726
# 565           0.10340         0.14400              0.09791         0.1752
# 566               NaN         0.09251              0.05302         0.1590
# 567           0.27700         0.35140              0.15200         0.2397
# 568           0.04362         0.00000              0.00000         0.1587
#
#      mean fractal dimension  ...  worst texture  worst perimeter  worst area  \
# 0                   0.07871  ...            NaN           184.60      2019.0
# 1                   0.05667  ...          23.41           158.80      1956.0
# 2                       NaN  ...          25.53           152.50      1709.0
# 3                   0.09744  ...          26.50              NaN       567.7
# 4                   0.05883  ...          16.67           152.20         NaN
# ..                      ...  ...            ...              ...         ...
# 564                 0.05623  ...          26.40              NaN      2027.0
# 565                 0.05533  ...            NaN           155.00      1731.0
# 566                 0.05648  ...          34.12           126.70      1124.0
# 567                 0.07016  ...          39.42           184.60      1821.0
# 568                 0.05884  ...            NaN            59.16       268.6
#
#      worst smoothness  worst compactness  worst concavity  \
# 0             0.16220            0.66560           0.7119
# 1             0.12380            0.18660           0.2416
# 2             0.14440            0.42450           0.4504
# 3             0.20980            0.86630              NaN
# 4             0.13740            0.20500           0.4000
# ..                ...                ...              ...
# 564           0.14100                NaN              NaN
# 565           0.11660            0.19220           0.3215
# 566           0.11390                NaN              NaN
# 567           0.16500            0.86810           0.9387
# 568           0.08996            0.06444              NaN
#
#      worst concave points  worst symmetry  worst fractal dimension  target
# 0                  0.2654          0.4601                  0.11890     0.0
# 1                  0.1860          0.2750                  0.08902     0.0
# 2                  0.2430          0.3613                      NaN     0.0
# 3                  0.2575          0.6638                      NaN     0.0
# 4                  0.1625          0.2364                  0.07678     0.0
# ..                    ...             ...                      ...     ...
# 564                0.2216          0.2060                  0.07115     0.0
# 565                0.1628             NaN                  0.06637     0.0
# 566                0.1418          0.2218                  0.07820     0.0
# 567                0.2650          0.4087                  0.12400     0.0
# 568                0.0000          0.2871                  0.07039     1.0
#
# [511 rows x 31 columns]

# %% [markdown]
# <section id="DuplicatesAdjusting">
#     <h4> 2.1.1. Duplicates </h4>
# </section>

# %%
num_duplicates = 555

random_index = np.random.choice(df_origin_missing.index, num_duplicates, replace=True)

duplicates = df_origin_missing.loc[random_index]

df_origin_missing_duplicate = pd.concat([df_origin_missing, duplicates])

df_origin_missing_duplicate.reset_index(drop=True, inplace=True)

# %%
df_origin_missing_duplicate
# Out:
#       mean radius  mean texture  mean perimeter  mean area  mean smoothness  \
# 0           17.99         10.38          122.80        NaN          0.11840
# 1             NaN         17.77          132.90     1326.0          0.08474
# 2           19.69         21.25          130.00     1203.0          0.10960
# 3           11.42         20.38           77.58      386.1          0.14250
# 4           20.29         14.34          135.10     1297.0          0.10030
# ...           ...           ...             ...        ...              ...
# 1061        14.99         22.11             NaN      693.7          0.08515
# 1062        10.32           NaN           65.31      324.9          0.09434
# 1063          NaN         17.30           81.25      489.9          0.10280
# 1064        11.41         10.82           73.34      403.3          0.09373
# 1065        15.10         16.39           99.58      674.5          0.11500
#
#       mean compactness  mean concavity  mean concave points  mean symmetry  \
# 0              0.27760         0.30010             0.147100         0.2419
# 1              0.07864         0.08690             0.070170         0.1812
# 2              0.15990         0.19740             0.127900         0.2069
# 3              0.28390         0.24140             0.105200         0.2597
# 4              0.13280         0.19800             0.104300         0.1809
# ...                ...             ...                  ...            ...
# 1061               NaN         0.06859             0.038760         0.1944
# 1062           0.04994         0.01012             0.005495         0.1885
# 1063           0.07664         0.03193             0.021070         0.1707
# 1064           0.06685             NaN             0.026230         0.1667
# 1065           0.18070         0.11380             0.085340         0.2001
#
#       mean fractal dimension  ...  worst texture  worst perimeter  worst area  \
# 0                    0.07871  ...            NaN           184.60      2019.0
# 1                    0.05667  ...          23.41           158.80      1956.0
# 2                        NaN  ...          25.53           152.50      1709.0
# 3                    0.09744  ...          26.50              NaN       567.7
# 4                    0.05883  ...          16.67           152.20         NaN
# ...                      ...  ...            ...              ...         ...
# 1061                 0.05913  ...          31.55           110.20       867.1
# 1062                 0.06201  ...          21.77            71.12       384.9
# 1063                 0.05984  ...          21.10            88.70       574.4
# 1064                 0.06113  ...          15.97            83.74       510.5
# 1065                 0.06467  ...          18.33           105.90       762.6
#
#       worst smoothness  worst compactness  worst concavity  \
# 0               0.1622            0.66560          0.71190
# 1               0.1238            0.18660          0.24160
# 2               0.1444            0.42450          0.45040
# 3               0.2098            0.86630              NaN
# 4               0.1374            0.20500          0.40000
# ...                ...                ...              ...
# 1061            0.1077                NaN          0.31140
# 1062               NaN            0.08842          0.04384
# 1063               NaN            0.12120          0.10200
# 1064            0.1548            0.23900          0.21020
# 1065            0.1386            0.28830          0.19600
#
#       worst concave points  worst symmetry  worst fractal dimension  target
# 0                  0.26540          0.4601                  0.11890     0.0
# 1                  0.18600          0.2750                  0.08902     0.0
# 2                  0.24300          0.3613                      NaN     0.0
# 3                  0.25750          0.6638                      NaN     0.0
# 4                  0.16250          0.2364                  0.07678     0.0
# ...                    ...             ...                      ...     ...
# 1061               0.13080          0.3163                  0.09251     1.0
# 1062                   NaN          0.2681                  0.07399     1.0
# 1063               0.05602          0.2688                  0.06888     1.0
# 1064               0.08958          0.3016                  0.08523     1.0
# 1065               0.14230          0.2590                      NaN     1.0
#
# [1066 rows x 31 columns]

# %% [markdown]
# <section id="Spliting">
#     <h3> 2.2. Spliting the dataframe </h3>
# </section>

# %%
X_train, y_train, X_validation, y_validation, X_test, y_test = train_valid_test_split(
                                                        df_origin_missing_duplicate,
                                                        target = 'target',
                                                        train_size=0.8,
                                                        valid_size=0.1,
                                                        test_size=0.1)

# %% [markdown]
# <section id="Saving">
#     <h3> 2.3. Saving of the data </h3>
# </section>

# %%
X_train.to_parquet('X_train.parquet', index=False)
X_test.to_parquet('X_test.parquet', index=False)
X_validation.to_parquet('X_validation.parquet', index=False)

# %% [markdown]
# ---

# %% [markdown]
# <section id="Functions">
#     <h2> 3. Functions definitions </h2>
# </section>

# %% [markdown]
# <section id="Initial">
#     <h3> 3.1. Initial informations </h3>
# </section>

# %%
def eda_initial_informations(df):
    
    num_rows, num_columns = df.shape
    index = df.index
    
    print('Number of rows:', num_rows)
    print('Number of columns:', num_columns)
    print('Index:', index)

# %% [markdown]
# <section id="Overview">
#     <h3> 3.2. Overview </h3>
# </section>

# %%
 def eda_overview(df):
    summary_df = eda.df_info(df)
    display_all(summary_df)

# %%
def eda_summary_table(df):
    num_missing = df.isnull().sum()
    percent_missing = (num_missing / len(df) * 100)
    percent_missing = percent_missing.round().astype(int)
    formats = df.dtypes
    types = formats.apply(lambda x: 
        'Numeric' if x in ['float64', 'int64'] else 
        'Categorical' if x == 'object' else 
        'Datetime' if x == 'datetime64[ns]' else 'Outro'
    )    
    
    num_occurrences = df.apply(lambda x: len(x.unique()))
    
    missing_table = pd.DataFrame({
        'Number of missing': num_missing,
        'Percent of missing (%)': percent_missing,
        'Number of occurrences': num_occurrences,
        'Format': formats,
        'Type': types
    })
    
    return missing_table

# %% [markdown]
# <section id="DistributionsFunction">
#     <h3> 3.3. Variables distributions </h3>
# </section>

# %%
def eda_variables_distributions(dataframe1, dataframe2, n_start, n_end):
    if n_end <= n_start:
        print('Error: n_end must be greater than n_start.')
        return
    
    variables = dataframe1.columns[n_start:n_end]
    num_variables = len(variables)
    
    if num_variables <= 0:
        print('Error: Invalid range of columns.')
        return
    
    num_cols = 2
    num_rows = (num_variables + 1) // num_cols
    fig, axes = plt.subplots(num_rows, num_cols, figsize=(12, 4*num_rows))
    
    if num_rows == 1 and num_cols == 1:
        axes = [axes]
    else:
        axes = axes.flatten()
    
    for i, var in enumerate(variables):
        axes[i].hist(dataframe1[var], bins=20, color='skyblue', alpha=0.5, label='Dataframe 1', log=True)
        axes[i].hist(dataframe2[var], bins=20, color='orange', alpha=0.5, label='Dataframe 2', log=True)
        #axes[i].set_title(var)
        axes[i].set_xlabel(var)
        axes[i].set_ylabel('Frequency')
        axes[i].legend()
    
    for j in range(i + 1, len(axes)):
        fig.delaxes(axes[j])
    
    plt.tight_layout()
    plt.show()

# Exemplo de uso:
# eda_variables_distributions(dataframe1, dataframe2, n_start, n_end)

# %% [markdown]
# <section id="ProportionFunction">
#     <h3> 3.4. Target proportion </h3>
# </section>

# %%
def eda_target_distribution(original_series, train_series, test_series, validation_series):
    labels = ['Class 0', 'Class 1']  # Defina os rótulos apropriados para suas classes
    
    # Crie subplots para os quatro gráficos de pizza
    fig, axes = plt.subplots(2, 2, figsize=(10, 10))
    fig.suptitle('Target Distribution Comparison', fontsize=16)
    axes = axes.flatten()

    series_data = [original_series, train_series, test_series, validation_series]
    titles = ['Original Series', 'Train Series', 'Test Series', 'Validation Series']
    
    for ax, data, title in zip(axes, series_data, titles):
        class_counts = [len(data[data == 0]), len(data[data == 1])]  # Calcule a contagem de classes 0 e 1
        
        wedges, texts, autotexts = ax.pie(class_counts, labels=labels, startangle=90, colors=['palegreen', 'lightcoral'],
                                          wedgeprops={'edgecolor': 'black'}, autopct='%1.1f%%')
        ax.axis('equal')  # Proporção igual para garantir que o gráfico de pizza seja um círculo
        ax.set_title(title)

        # Adicione o número absoluto das classes aos rótulos
        for autotext, count in zip(autotexts, class_counts):
            autotext.set(size=12, fontweight='bold')
            autotext.set_text(f'{count}\n({autotext.get_text()})')

    plt.tight_layout(rect=[0, 0.03, 1, 0.95])
    plt.show()

# %% [markdown]
# ---

# %% [markdown]
# <section id="EDAResults">
#     <h2> 4. Exploratory Data Analysis Results </h2>
# </section>

# %% [markdown]
# <section id="InitialResults">
#     <h3> 4.1. Initial informations </h3>
# </section>

# %%
eda_initial_informations(df_origin)
# Out:
# Number of rows: 569
# Number of columns: 31
# Index: RangeIndex(start=0, stop=569, step=1)

# %% [markdown]
# <section id="OverviewResults">
#     <h3> 4.2. Overview </h3>
# </section>

# %%
eda_overview(df_origin)
# Out:
#                         data_type data_type_grp num_unique_values  \
# mean radius               float64     Numerical               427
# mean texture              float64     Numerical               429
# mean perimeter            float64     Numerical               464
# mean area                 float64     Numerical               492
# mean smoothness           float64     Numerical               432
# mean compactness          float64     Numerical               487
# mean concavity            float64     Numerical               496
# mean concave points       float64     Numerical               470
# mean symmetry             float64     Numerical               400
# mean fractal dimension    float64     Numerical               453
# radius error              float64     Numerical               490
# texture error             float64     Numerical               470
# perimeter error           float64     Numerical               482
# area error                float64     Numerical               472
# smoothness error          float64     Numerical               497
# compactness error         float64     Numerical               481
# concavity error           float64     Numerical               475
# concave points error      float64     Numerical               453
# symmetry error            float64     Numerical               451
# fractal dimension error   float64     Numerical               484
# worst radius              float64     Numerical               417
# worst texture             float64     Numerical               466
# worst perimeter           float64     Numerical               455
# worst area                float64     Numerical               489
# worst smoothness          float64     Numerical               385
# worst compactness         float64     Numerical               491
# worst concavity           float64     Numerical               489
# worst concave points      float64     Numerical               440
# worst symmetry            float64     Numerical               456
# worst fractal dimension   float64     Numerical               490
# target                    float64     Numerical                 2
#
#                                                       sample_unique_values  \
# mean radius              [17.99, nan, 19.69, 11.42, 20.29, 12.45, 18.25...
# mean texture             [10.38, 17.77, 21.25, 20.38, 14.34, 15.7, 19.9...
# mean perimeter           [122.8, 132.9, 130.0, 77.58, 135.1, 82.57, 119...
# mean area                [nan, 1326.0, 1203.0, 386.1, 1297.0, 477.1, 10...
# mean smoothness          [0.1184, 0.08474, 0.1096, 0.1425, 0.1003, 0.12...
# mean compactness         [0.2776, 0.07864, 0.1599, 0.2839, 0.1328, 0.17...
# mean concavity           [0.3001, 0.0869, 0.1974, 0.2414, 0.198, 0.1578...
# mean concave points      [0.1471, 0.07017, 0.1279, 0.1052, 0.1043, 0.08...
# mean symmetry            [0.2419, 0.1812, 0.2069, 0.2597, 0.1809, 0.208...
# mean fractal dimension   [0.07871, 0.05667, nan, 0.09744, 0.05883, 0.07...
# radius error             [1.095, 0.5435, 0.7456, 0.4956, 0.7572, 0.3345...
# texture error            [0.9053, 0.7339, 0.7869, 1.156, 0.7813, 0.8902...
# perimeter error          [8.589, 3.398, 4.585, 3.445, 5.438, 2.217, 3.1...
# area error               [153.4, 74.08, 94.03, 27.23, 94.44, nan, 53.91...
# smoothness error         [0.006399, 0.005225, 0.00615, nan, 0.01149, 0....
# compactness error        [0.04904, 0.01308, 0.04006, 0.07458, 0.02461, ...
# concavity error          [0.05373, 0.0186, 0.03832, 0.05661, 0.05688, 0...
# concave points error     [0.01587, 0.0134, 0.02058, 0.01867, 0.01885, 0...
# symmetry error           [0.03003, 0.01389, 0.0225, 0.05963, 0.01756, 0...
# fractal dimension error  [nan, 0.003532, 0.004571, 0.009208, 0.005115, ...
# worst radius             [25.38, 24.99, 23.57, 14.91, 22.54, 15.47, 22....
# worst texture            [nan, 23.41, 25.53, 26.5, 16.67, 23.75, 28.14,...
# worst perimeter          [184.6, 158.8, 152.5, nan, 152.2, 103.4, 153.2...
# worst area               [2019.0, 1956.0, 1709.0, 567.7, nan, 741.6, 16...
# worst smoothness         [0.1622, 0.1238, 0.1444, 0.2098, 0.1374, 0.179...
# worst compactness        [0.6656, 0.1866, 0.4245, 0.8663, 0.205, 0.5249...
# worst concavity          [0.7119, 0.2416, 0.4504, nan, 0.4, 0.5355, 0.3...
# worst concave points     [0.2654, 0.186, 0.243, 0.2575, 0.1625, 0.1741,...
# worst symmetry           [0.4601, 0.275, 0.3613, 0.6638, 0.2364, nan, 0...
# worst fractal dimension  [0.1189, 0.08902, nan, 0.07678, 0.08368, 0.115...
# target                                                     [0.0, 1.0, nan]
#
#                         num_missing perc_missing
# mean radius                      52      9.13884
# mean texture                     74    13.005272
# mean perimeter                   71    12.478032
# mean area                        48     8.435852
# mean smoothness                  54     9.490334
# mean compactness                 55     9.666081
# mean concavity                   46     8.084359
# mean concave points              75    13.181019
# mean symmetry                    60    10.544815
# mean fractal dimension           57    10.017575
# radius error                     54     9.490334
# texture error                    59    10.369069
# perimeter error                  55     9.666081
# area error                       62    10.896309
# smoothness error                 56     9.841828
# compactness error                65     11.42355
# concavity error                  69    12.126538
# concave points error             66    11.599297
# symmetry error                   61    10.720562
# fractal dimension error          64    11.247803
# worst radius                     53     9.314587
# worst texture                    55     9.666081
# worst perimeter                  71    12.478032
# worst area                       58    10.193322
# worst smoothness                 65     11.42355
# worst compactness                49     8.611599
# worst concavity                  56     9.841828
# worst concave points             68    11.950791
# worst symmetry                   58    10.193322
# worst fractal dimension          51     8.963093
# target                           58    10.193322

# %%
eda_summary_table(df_origin)
# Out:
#                          Number of missing  Percent of missing (%)  \
# mean radius                             52                       9
# mean texture                            74                      13
# mean perimeter                          71                      12
# mean area                               48                       8
# mean smoothness                         54                       9
# mean compactness                        55                      10
# mean concavity                          46                       8
# mean concave points                     75                      13
# mean symmetry                           60                      11
# mean fractal dimension                  57                      10
# radius error                            54                       9
# texture error                           59                      10
# perimeter error                         55                      10
# area error                              62                      11
# smoothness error                        56                      10
# compactness error                       65                      11
# concavity error                         69                      12
# concave points error                    66                      12
# symmetry error                          61                      11
# fractal dimension error                 64                      11
# worst radius                            53                       9
# worst texture                           55                      10
# worst perimeter                         71                      12
# worst area                              58                      10
# worst smoothness                        65                      11
# worst compactness                       49                       9
# worst concavity                         56                      10
# worst concave points                    68                      12
# worst symmetry                          58                      10
# worst fractal dimension                 51                       9
# target                                  58                      10
#
#                          Number of occurrences   Format     Type
# mean radius                                428  float64  Numeric
# mean texture                               430  float64  Numeric
# mean perimeter                             465  float64  Numeric
# mean area                                  493  float64  Numeric
# mean smoothness                            433  float64  Numeric
# mean compactness                           488  float64  Numeric
# mean concavity                             497  float64  Numeric
# mean concave points                        471  float64  Numeric
# mean symmetry                              401  float64  Numeric
# mean fractal dimension                     454  float64  Numeric
# radius error                               491  float64  Numeric
# texture error                              471  float64  Numeric
# perimeter error                            483  float64  Numeric
# area error                                 473  float64  Numeric
# smoothness error                           498  float64  Numeric
# compactness error                          482  float64  Numeric
# concavity error                            476  float64  Numeric
# concave points error                       454  float64  Numeric
# symmetry error                             452  float64  Numeric
# fractal dimension error                    485  float64  Numeric
# worst radius                               418  float64  Numeric
# worst texture                              467  float64  Numeric
# worst perimeter                            456  float64  Numeric
# worst area                                 490  float64  Numeric
# worst smoothness                           386  float64  Numeric
# worst compactness                          492  float64  Numeric
# worst concavity                            490  float64  Numeric
# worst concave points                       441  float64  Numeric
# worst symmetry                             457  float64  Numeric
# worst fractal dimension                    491  float64  Numeric
# target                                       3  float64  Numeric

# %% [markdown]
# <section id="DistributionsResults">
#     <h3> 4.3. Variables Distributions </h3>
# </section>

# %%
eda_variables_distributions(X_test, X_validation, 3, 9)

# %% [markdown]
# <section id="ProportionResults">
#     <h3> 4.4. Target proportion </h3>
# </section>

# %%
eda_target_distribution(y_origin, y_train, y_test, y_validation)
