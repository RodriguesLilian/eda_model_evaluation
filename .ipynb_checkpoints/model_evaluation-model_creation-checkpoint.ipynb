# %% [markdown]
# # Model Evaluation (model creation)

# %% [markdown]
# ## Table of contents
#
# 0. [Introduction](#Introduction)
# 1. [Import of packages](#Packages)
# 2. [Import of data](#Data)
# 3. [Functions definitions](#Functions)
#     1. [Overview](#Overview)
# 4. [Exploratory Data Analysis Results](#EDAResults)
#     1. [Overview](#OverviewResults)

# %% [markdown]
# <section id="Introduction">
#     <h2> 0. Introduction </h2>
# </section>

# %% [markdown]
# This is a file with functions that aim to facilitate exploratory data analysis. As output, the functions provide graphs, metrics, and basic tables commonly used in the analysis process. Pay attention to the function parameters:
#
# - **df_origin**: single pandas dataframe;
#
# <br>
#
# - **X_train**: pandas train dataframe;
# - **X_test**: pandas test dataframe;
# - **X_validation**: pandas validation dataframe;
#
# <br>
#
# - **y_train**: train target;
# - **y_test**: test target;
# - **y_validation**: validation target;

# %% [markdown]
# ---

# %% [markdown]
# <section id="Packages">
#     <h2> 1. Import of packages </h2>
# </section>

# %%
#!pip install fast_ml

# %%
from sklearn.datasets import load_breast_cancer

from fast_ml import eda
from fast_ml.model_development import train_valid_test_split
from fast_ml.utilities import reduce_memory_usage, display_all

import pandas as pd # parquet
import pickle # pickle

# interative interface
import ipywidgets as widgets
from IPython.display import display

# %% [markdown]
# <section id="Data">
#     <h2> 2. Import of data </h2>
# </section>

# %%
X_origin, y_origin = load_breast_cancer(return_X_y=True, as_frame=True)

# %%
y_dataframe = pd.DataFrame(y, columns=['target'])

# %%
df_origin = pd.concat([X, y_dataframe], axis=1)

# %%
df_origin
# Out:
#      mean radius  mean texture  mean perimeter  mean area  mean smoothness  \
# 0          17.99         10.38          122.80     1001.0          0.11840
# 1          20.57         17.77          132.90     1326.0          0.08474
# 2          19.69         21.25          130.00     1203.0          0.10960
# 3          11.42         20.38           77.58      386.1          0.14250
# 4          20.29         14.34          135.10     1297.0          0.10030
# ..           ...           ...             ...        ...              ...
# 564        21.56         22.39          142.00     1479.0          0.11100
# 565        20.13         28.25          131.20     1261.0          0.09780
# 566        16.60         28.08          108.30      858.1          0.08455
# 567        20.60         29.33          140.10     1265.0          0.11780
# 568         7.76         24.54           47.92      181.0          0.05263
#
#      mean compactness  mean concavity  mean concave points  mean symmetry  \
# 0             0.27760         0.30010              0.14710         0.2419
# 1             0.07864         0.08690              0.07017         0.1812
# 2             0.15990         0.19740              0.12790         0.2069
# 3             0.28390         0.24140              0.10520         0.2597
# 4             0.13280         0.19800              0.10430         0.1809
# ..                ...             ...                  ...            ...
# 564           0.11590         0.24390              0.13890         0.1726
# 565           0.10340         0.14400              0.09791         0.1752
# 566           0.10230         0.09251              0.05302         0.1590
# 567           0.27700         0.35140              0.15200         0.2397
# 568           0.04362         0.00000              0.00000         0.1587
#
#      mean fractal dimension  ...  worst texture  worst perimeter  worst area  \
# 0                   0.07871  ...          17.33           184.60      2019.0
# 1                   0.05667  ...          23.41           158.80      1956.0
# 2                   0.05999  ...          25.53           152.50      1709.0
# 3                   0.09744  ...          26.50            98.87       567.7
# 4                   0.05883  ...          16.67           152.20      1575.0
# ..                      ...  ...            ...              ...         ...
# 564                 0.05623  ...          26.40           166.10      2027.0
# 565                 0.05533  ...          38.25           155.00      1731.0
# 566                 0.05648  ...          34.12           126.70      1124.0
# 567                 0.07016  ...          39.42           184.60      1821.0
# 568                 0.05884  ...          30.37            59.16       268.6
#
#      worst smoothness  worst compactness  worst concavity  \
# 0             0.16220            0.66560           0.7119
# 1             0.12380            0.18660           0.2416
# 2             0.14440            0.42450           0.4504
# 3             0.20980            0.86630           0.6869
# 4             0.13740            0.20500           0.4000
# ..                ...                ...              ...
# 564           0.14100            0.21130           0.4107
# 565           0.11660            0.19220           0.3215
# 566           0.11390            0.30940           0.3403
# 567           0.16500            0.86810           0.9387
# 568           0.08996            0.06444           0.0000
#
#      worst concave points  worst symmetry  worst fractal dimension  target
# 0                  0.2654          0.4601                  0.11890       0
# 1                  0.1860          0.2750                  0.08902       0
# 2                  0.2430          0.3613                  0.08758       0
# 3                  0.2575          0.6638                  0.17300       0
# 4                  0.1625          0.2364                  0.07678       0
# ..                    ...             ...                      ...     ...
# 564                0.2216          0.2060                  0.07115       0
# 565                0.1628          0.2572                  0.06637       0
# 566                0.1418          0.2218                  0.07820       0
# 567                0.2650          0.4087                  0.12400       0
# 568                0.0000          0.2871                  0.07039       1
#
# [569 rows x 31 columns]

# %%
X_train, y_train, X_validation, y_validation, X_test, y_test = train_valid_test_split(df_origin,
                                                        target = 'target',
                                                        train_size=0.8,
                                                        valid_size=0.1,
                                                        test_size=0.1)

# %% [markdown]
# ---

# %% [markdown]
# <section id="Functions">
#     <h2> 3. Functions definitions </h2>
# </section>

# %% [markdown]
# <section id="Overview">
#     <h3> 3.1. Overview </h3>
# </section>

# %%
 def eda_overview(df):
    summary_df = eda.df_info(df)
    display_all(summary_df)

# %% [markdown]
# ---

# %% [markdown]
# <section id="EDAResults">
#     <h2> 4. Exploratory Data Analysis Results </h2>
# </section>

# %% [markdown]
# <section id="OverviewgResults">
#     <h3> 4.1. Overview </h3>
# </section>

# %%
eda_overview(df_origin)
# Out:
#                         data_type data_type_grp num_unique_values  \
# mean radius               float64     Numerical               456
# mean texture              float64     Numerical               479
# mean perimeter            float64     Numerical               522
# mean area                 float64     Numerical               539
# mean smoothness           float64     Numerical               474
# mean compactness          float64     Numerical               537
# mean concavity            float64     Numerical               537
# mean concave points       float64     Numerical               542
# mean symmetry             float64     Numerical               432
# mean fractal dimension    float64     Numerical               499
# radius error              float64     Numerical               540
# texture error             float64     Numerical               519
# perimeter error           float64     Numerical               533
# area error                float64     Numerical               528
# smoothness error          float64     Numerical               547
# compactness error         float64     Numerical               541
# concavity error           float64     Numerical               533
# concave points error      float64     Numerical               507
# symmetry error            float64     Numerical               498
# fractal dimension error   float64     Numerical               545
# worst radius              float64     Numerical               457
# worst texture             float64     Numerical               511
# worst perimeter           float64     Numerical               514
# worst area                float64     Numerical               544
# worst smoothness          float64     Numerical               411
# worst compactness         float64     Numerical               529
# worst concavity           float64     Numerical               539
# worst concave points      float64     Numerical               492
# worst symmetry            float64     Numerical               500
# worst fractal dimension   float64     Numerical               535
# target                      int64     Numerical                 2
#
#                                                       sample_unique_values  \
# mean radius              [17.99, 20.57, 19.69, 11.42, 20.29, 12.45, 18....
# mean texture             [10.38, 17.77, 21.25, 20.38, 14.34, 15.7, 19.9...
# mean perimeter           [122.8, 132.9, 130.0, 77.58, 135.1, 82.57, 119...
# mean area                [1001.0, 1326.0, 1203.0, 386.1, 1297.0, 477.1,...
# mean smoothness          [0.1184, 0.08474, 0.1096, 0.1425, 0.1003, 0.12...
# mean compactness         [0.2776, 0.07864, 0.1599, 0.2839, 0.1328, 0.17...
# mean concavity           [0.3001, 0.0869, 0.1974, 0.2414, 0.198, 0.1578...
# mean concave points      [0.1471, 0.07017, 0.1279, 0.1052, 0.1043, 0.08...
# mean symmetry            [0.2419, 0.1812, 0.2069, 0.2597, 0.1809, 0.208...
# mean fractal dimension   [0.07871, 0.05667, 0.05999, 0.09744, 0.05883, ...
# radius error             [1.095, 0.5435, 0.7456, 0.4956, 0.7572, 0.3345...
# texture error            [0.9053, 0.7339, 0.7869, 1.156, 0.7813, 0.8902...
# perimeter error          [8.589, 3.398, 4.585, 3.445, 5.438, 2.217, 3.1...
# area error               [153.4, 74.08, 94.03, 27.23, 94.44, 27.19, 53....
# smoothness error         [0.006399, 0.005225, 0.00615, 0.00911, 0.01149...
# compactness error        [0.04904, 0.01308, 0.04006, 0.07458, 0.02461, ...
# concavity error          [0.05373, 0.0186, 0.03832, 0.05661, 0.05688, 0...
# concave points error     [0.01587, 0.0134, 0.02058, 0.01867, 0.01885, 0...
# symmetry error           [0.03003, 0.01389, 0.0225, 0.05963, 0.01756, 0...
# fractal dimension error  [0.006193, 0.003532, 0.004571, 0.009208, 0.005...
# worst radius             [25.38, 24.99, 23.57, 14.91, 22.54, 15.47, 22....
# worst texture            [17.33, 23.41, 25.53, 26.5, 16.67, 23.75, 27.6...
# worst perimeter          [184.6, 158.8, 152.5, 98.87, 152.2, 103.4, 153...
# worst area               [2019.0, 1956.0, 1709.0, 567.7, 1575.0, 741.6,...
# worst smoothness         [0.1622, 0.1238, 0.1444, 0.2098, 0.1374, 0.179...
# worst compactness        [0.6656, 0.1866, 0.4245, 0.8663, 0.205, 0.5249...
# worst concavity          [0.7119, 0.2416, 0.4504, 0.6869, 0.4, 0.5355, ...
# worst concave points     [0.2654, 0.186, 0.243, 0.2575, 0.1625, 0.1741,...
# worst symmetry           [0.4601, 0.275, 0.3613, 0.6638, 0.2364, 0.3985...
# worst fractal dimension  [0.1189, 0.08902, 0.08758, 0.173, 0.07678, 0.1...
# target                                                              [0, 1]
#
#                         num_missing perc_missing
# mean radius                       0          0.0
# mean texture                      0          0.0
# mean perimeter                    0          0.0
# mean area                         0          0.0
# mean smoothness                   0          0.0
# mean compactness                  0          0.0
# mean concavity                    0          0.0
# mean concave points               0          0.0
# mean symmetry                     0          0.0
# mean fractal dimension            0          0.0
# radius error                      0          0.0
# texture error                     0          0.0
# perimeter error                   0          0.0
# area error                        0          0.0
# smoothness error                  0          0.0
# compactness error                 0          0.0
# concavity error                   0          0.0
# concave points error              0          0.0
# symmetry error                    0          0.0
# fractal dimension error           0          0.0
# worst radius                      0          0.0
# worst texture                     0          0.0
# worst perimeter                   0          0.0
# worst area                        0          0.0
# worst smoothness                  0          0.0
# worst compactness                 0          0.0
# worst concavity                   0          0.0
# worst concave points              0          0.0
# worst symmetry                    0          0.0
# worst fractal dimension           0          0.0
# target                            0          0.0
